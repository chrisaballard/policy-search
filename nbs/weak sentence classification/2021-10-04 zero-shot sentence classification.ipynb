# %% [markdown]
# # Zero-shot classifiers as a noisy label source
#
# At sentence level within parsed policy documents.

# %%
# notebook-specific dependencies

# !python -m pip install torch transformers
# Out:
# Requirement already satisfied: torch in /Users/kalyan/Documents/CPR/policy-search/.venv/lib/python3.8/site-packages (1.8.1)
# Requirement already satisfied: transformers in /Users/kalyan/Documents/CPR/policy-search/.venv/lib/python3.8/site-packages (4.6.1)
# Requirement already satisfied: typing-extensions in /Users/kalyan/Documents/CPR/policy-search/.venv/lib/python3.8/site-packages (from torch) (3.10.0.2)
# Requirement already satisfied: numpy in /Users/kalyan/Documents/CPR/policy-search/.venv/lib/python3.8/site-packages (from torch) (1.21.1)
# Requirement already satisfied: packaging in /Users/kalyan/Documents/CPR/policy-search/.venv/lib/python3.8/site-packages (from transformers) (21.0)
# Requirement already satisfied: huggingface-hub==0.0.8 in /Users/kalyan/Documents/CPR/policy-search/.venv/lib/python3.8/site-packages (from transformers) (0.0.8)
# Requirement already satisfied: filelock in /Users/kalyan/Documents/CPR/policy-search/.venv/lib/python3.8/site-packages (from transformers) (3.0.12)
# Requirement already satisfied: requests in /Users/kalyan/Documents/CPR/policy-search/.venv/lib/python3.8/site-packages (from transformers) (2.26.0)
# Requirement already satisfied: tokenizers<0.11,>=0.10.1 in /Users/kalyan/Documents/CPR/policy-search/.venv/lib/python3.8/site-packages (from transformers) (0.10.3)
# Requirement already satisfied: tqdm>=4.27 in /Users/kalyan/Documents/CPR/policy-search/.venv/lib/python3.8/site-packages (from transformers) (4.62.3)
# Requirement already satisfied: regex!=2019.12.17 in /Users/kalyan/Documents/CPR/policy-search/.venv/lib/python3.8/site-packages (from transformers) (2021.8.28)
# Requirement already satisfied: sacremoses in /Users/kalyan/Documents/CPR/policy-search/.venv/lib/python3.8/site-packages (from transformers) (0.0.45)
# Requirement already satisfied: pyparsing>=2.0.2 in /Users/kalyan/Documents/CPR/policy-search/.venv/lib/python3.8/site-packages (from packaging->transformers) (2.4.7)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/kalyan/Documents/CPR/policy-search/.venv/lib/python3.8/site-packages (from requests->transformers) (2021.5.30)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/kalyan/Documents/CPR/policy-search/.venv/lib/python3.8/site-packages (from requests->transformers) (1.26.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /Users/kalyan/Documents/CPR/policy-search/.venv/lib/python3.8/site-packages (from requests->transformers) (2.0.6)
# Requirement already satisfied: idna<4,>=2.5 in /Users/kalyan/Documents/CPR/policy-search/.venv/lib/python3.8/site-packages (from requests->transformers) (3.2)
# Requirement already satisfied: joblib in /Users/kalyan/Documents/CPR/policy-search/.venv/lib/python3.8/site-packages (from sacremoses->transformers) (1.0.1)
# Requirement already satisfied: six in /Users/kalyan/Documents/CPR/policy-search/.venv/lib/python3.8/site-packages (from sacremoses->transformers) (1.16.0)
# Requirement already satisfied: click in /Users/kalyan/Documents/CPR/policy-search/.venv/lib/python3.8/site-packages (from sacremoses->transformers) (8.0.1)

# %%
from pathlib import Path

import yaml
import pandas as pd
from transformers import pipeline

from utils import Schema, ZeroShotClassifier, load_policy_dataset

# %%
def flatten_list_of_lists(l: list) -> list:
    """
    [[1, 2], [3]] -> [1, 2, 3]
    [[1, 2], 3] -> [1, 2, 3]
    """

    res = []

    for item in l:
        if isinstance(item, list):
            res = res + item
        else:
            res.append(item)

    return res

# %%
df = load_policy_dataset()

df.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1666918 entries, 0 to 1666917
# Data columns (total 4 columns):
#  #   Column       Non-Null Count    Dtype
# ---  ------       --------------    -----
#  0   policy_id    1666918 non-null  int64
#  1   policy_name  1666918 non-null  object
#  2   page_id      1666918 non-null  int64
#  3   text         1666918 non-null  object
# dtypes: int64(2), object(2)
# memory usage: 50.9+ MB

# %% [markdown]
# ## 1. Get class labels, download model
#
# ### 1a) Get class labels

# %%
SCHEMA_FOLDER = Path("../../schema/")

instruments = Schema.from_yaml_path(SCHEMA_FOLDER/"instruments.yml")
sectors = Schema.from_yaml_path(SCHEMA_FOLDER/"sectors.yml")

# %% [markdown]
# ### 1b) Get models
#
# This method is deprecated as wrapped in `utils.ZeroShotClassifier` (see 2)

# %% [markdown]
# #### typeform, distilbert MNLI

# %%
# typeform, distilbert MNLI: https://huggingface.co/typeform/distilbert-base-uncased-mnli
clf_bert = pipeline("zero-shot-classification", model="typeform/distilbert-base-uncased-mnli")
# Out:
# The `xla_device` argument has been deprecated in v4.4.0 of Transformers. It is ignored and you can safely remove it from your `config.json` file.
# The `xla_device` argument has been deprecated in v4.4.0 of Transformers. It is ignored and you can safely remove it from your `config.json` file.

# %%
text = """Support around £3.6 billion of investment to upgrade around a million homes through the Energy Company Obligation (ECO), and extend support for home energy efficiency improvements until 2028 at the current level of ECO funding"""

clf_bert(text, instruments.all_keywords, threshold=0.7)
# Out:
# {'sequence': 'Support around £3.6 billion of investment to upgrade around a million homes through the Energy Company Obligation (ECO), and extend support for home energy efficiency improvements until 2028 at the current level of ECO funding',
#  'labels': ['investment',
#   'obligations',
#   'funding',
#   'finance',
#   'interest',
#   'commons',
#   'resilience funding',
#   'financing structure',
#   'grants',
#   'structures',
#   'stakeholder engagement',
#   'capacity-building body',
#   'spatial zoning',
#   'infrastructure',
#   'multi-level governance',
#   'organisation',
#   'zoning',
#   'resilient infrastructure policy',
#   'equity in adaptation',
#   'energy efficiency rating',
#   'reporting',
#   'assessment',
#   'credits',
#   'strategy',
#   'bodies',
#   'information',
#   'green finance',
#   'strategic body',
#   'adaptation plan',
#   'responsibility',
#   'fiscal incentives',
#   'regulatory body',
#   'strategic plan',
#   'advice',
#   'financial flows',
#   'duty to set target',
#   'target',
#   'mandates',
#   'national strategy',
#   'evaluation',
#   'financial incentives',
#   'technology',
#   'labelling',
#   'planning',
#   'amending target',
#   'technical requirements',
#   'codes',
#   'technical assistance',
#   'projections',
#   'reporting information',
#   'resource management',
#   'processes',
#   'research body',
#   'political strategy',
#   'split incentives',
#   'product information',
#   'public infrastructure',
#   'committee',
#   'research and development',
#   'research scheme',
#   'standards',
#   'consultation',
#   'consumer information',
#   'research funding',
#   'local authority',
#   'national adaptation service',
#   'environmental assessment',
#   'public information',
#   'guideline',
#   'knowledge generation',
#   'scientific inquiries',
#   'research programme',
#   'site selection',
#   'white paper',
#   'guidelines',
#   'specification of grid standards',
#   'management',
#   'plan',
#   'risk screening',
#   'research collaboration',
#   'tax advantages',
#   'monitoring',
#   'insitutions',
#   'advisory body',
#   'protocol',
#   'market-based instruments',
#   'co-ordinating body',
#   'limit',
#   'inter-agency body',
#   'legally binding target',
#   'disclosure',
#   'auditing',
#   'joint research',
#   'loan',
#   'knowledge sharing and dissemination',
#   'planning body',
#   'low-carbon finance',
#   'education',
#   'risk assessments',
#   'federal adaptation programme',
#   'climate risk',
#   'sub-national government',
#   'social safety nets',
#   'national government',
#   'demonstration project',
#   'public-private partnerships',
#   'climate fund',
#   'training',
#   'municipal government',
#   'educational body',
#   'regulation',
#   'indigenous knowledge',
#   'professional training',
#   'tax relief',
#   'minimum',
#   'maximum',
#   'permits',
#   'cap and trade',
#   'packaging',
#   'procurement',
#   'tariff',
#   'emissions trading',
#   'knowledge distribution',
#   'public goods',
#   'climate vulnerabiliy',
#   'tax credits',
#   'carbon pricing',
#   'methane leak management',
#   'accelerated depreciation',
#   'public spending',
#   'carbon budget',
#   'international climate finance',
#   'smart subsidy',
#   'financial regulation',
#   'feed-in tariff',
#   'auction',
#   'subsidy',
#   'levy',
#   'debt support',
#   'early warning systems',
#   'tax system',
#   'taxes',
#   'fossil fuel subsidy',
#   'licensing'],
#  'scores': [0.8416982293128967,
#   0.021964510902762413,
#   0.010067985393106937,
#   0.0036869097966700792,
#   0.002155108842998743,
#   0.0020070017781108618,
#   0.0019306804751977324,
#   0.0018421926070004702,
#   0.0016623784322291613,
#   0.0015648056287318468,
#   0.0014993329532444477,
#   0.0014360918430611491,
#   0.001395516563206911,
#   0.0013266693567857146,
#   0.0013088028645142913,
#   0.0012700021034106612,
#   0.0012592884013429284,
#   0.001255398616194725,
#   0.0012509538792073727,
#   0.0012354152277112007,
#   0.0012246246915310621,
#   0.0012180859921500087,
#   0.0012084414483979344,
#   0.0011896052164956927,
#   0.0011790619464591146,
#   0.0011704947100952268,
#   0.0011537116952240467,
#   0.0011502646375447512,
#   0.001148783601820469,
#   0.001141360029578209,
#   0.0011330321431159973,
#   0.001131377648562193,
#   0.0011275530559942126,
#   0.0011117730755358934,
#   0.0011056778021156788,
#   0.0011055098148062825,
#   0.0010821199975907803,
#   0.001077447785064578,
#   0.0010556956985965371,
#   0.0010544003453105688,
#   0.0010450961999595165,
#   0.0010144633706659079,
#   0.0010118550853803754,
#   0.001005571917630732,
#   0.0010052102152258158,
#   0.0010001693153753877,
#   0.000999252893961966,
#   0.0009980988688766956,
#   0.0009979662718251348,
#   0.000995409907773137,
#   0.0009824621956795454,
#   0.0009822543943300843,
#   0.0009775375947356224,
#   0.0009731221944093704,
#   0.0009705303818918765,
#   0.0009687876445241272,
#   0.0009642572840675712,
#   0.0009637100738473237,
#   0.0009607095853425562,
#   0.0009600264020264149,
#   0.0009476475534029305,
#   0.0009362680139020085,
#   0.0009355805232189596,
#   0.0009307272848673165,
#   0.0009261547238565981,
#   0.0009248508722521365,
#   0.000920167425647378,
#   0.0009151825215667486,
#   0.0009095837012864649,
#   0.0009002415463328362,
#   0.0008891176548786461,
#   0.0008877304499037564,
#   0.0008867119322530925,
#   0.0008861793321557343,
#   0.0008818588103167713,
#   0.0008717507007531822,
#   0.0008713642600923777,
#   0.0008622200111858547,
#   0.0008599428692832589,
#   0.0008517294772900641,
#   0.0008497858652845025,
#   0.0008477432420477271,
#   0.0008301637135446072,
#   0.0008295270381495357,
#   0.0008276313892565668,
#   0.0008235668647103012,
#   0.0008160605211742222,
#   0.0008156261756084859,
#   0.000802710943389684,
#   0.0007977202185429633,
#   0.0007934984751045704,
#   0.0007908385014161468,
#   0.0007905724924057722,
#   0.0007866615196689963,
#   0.0007857862510718405,
#   0.0007834506104700267,
#   0.0007612075423821807,
#   0.0007588339503854513,
#   0.0007312454981729388,
#   0.0007304864702746272,
#   0.0007040019263513386,
#   0.0007008639513514936,
#   0.0006935512064956129,
#   0.0006926142377778888,
#   0.00068253482459113,
#   0.0006800319533795118,
#   0.0006778903189115226,
#   0.0006717873038724065,
#   0.0006497531430795789,
#   0.0006494970293715596,
#   0.0006458133575506508,
#   0.0006427816115319729,
#   0.0006418995326384902,
#   0.000630463648121804,
#   0.0006284340634010732,
#   0.0006161274504847825,
#   0.0005974200903438032,
#   0.000593518721871078,
#   0.0005928914179094136,
#   0.0005858512595295906,
#   0.0005724058137275279,
#   0.0005526700406335294,
#   0.0005443547270260751,
#   0.0005317000905051827,
#   0.00048402519314549863,
#   0.0004488766426220536,
#   0.0004433032008819282,
#   0.0004193837521597743,
#   0.00041582356789149344,
#   0.00039567312342114747,
#   0.0003943670599255711,
#   0.00038605296867899597,
#   0.0003752679913304746,
#   0.0003630850405897945,
#   0.0003199699567630887,
#   0.0002982960140798241,
#   0.00027663586661219597,
#   0.00027273938758298755,
#   0.0002467876474838704,
#   0.00024374006898142397,
#   0.0002125877799699083,
#   0.00020010684966109693,
#   0.0001821598270907998,
#   0.00013142502575647086]}

# %% [markdown]
# ## 2. Run zero-shot classifiers on a few examples
#
# Here we use `utils.ZeroShotClassifier` as a wrapper around the huggingface model.

# %%
n_examples = 30
examples = df.sample(n_examples, random_state=99)['text'].tolist()

clf_instruments = ZeroShotClassifier(instruments)
clf_sectors = ZeroShotClassifier(sectors)
# Out:
# The `xla_device` argument has been deprecated in v4.4.0 of Transformers. It is ignored and you can safely remove it from your `config.json` file.
# The `xla_device` argument has been deprecated in v4.4.0 of Transformers. It is ignored and you can safely remove it from your `config.json` file.
# The `xla_device` argument has been deprecated in v4.4.0 of Transformers. It is ignored and you can safely remove it from your `config.json` file.
# The `xla_device` argument has been deprecated in v4.4.0 of Transformers. It is ignored and you can safely remove it from your `config.json` file.

# %%
clf_instruments.predict("test text", 0.8)
# Out:
# [('assessment', 'Monitoring and evaluation', 0.9998759031295776),
#  ('evaluation', 'Monitoring and evaluation', 0.9994389414787292),
#  ('information', 'Labelling and information', 0.9839628338813782),
#  ('interest', 'Finance', 0.8211902379989624)]

# %%
THRESHOLD = 0.8

for _str in examples:
    print(_str)
    print()
    print("INSTRUMENT PREDICTIONS")
    print("\n".join([f"- {pred}" for pred in clf_instruments.predict(_str, THRESHOLD)]))
    print()
    print("SECTOR PREDICTIONS")
    print("\n".join([f"- {pred}" for pred in clf_sectors.predict(_str, THRESHOLD)]))
    print("----------------------")
# Out:
# Sources of Energy Supply At present, Bangladesh has energy supply from both renewable and nonrenewable sources, 38 percent of which comes from biomass (Figure 3.1).
#
# INSTRUMENT PREDICTIONS
#
#
# SECTOR PREDICTIONS
# - ('renewable energy', 'Energy production', 0.9283546805381775)
# - ('biomass', 'Agriculture (general)', 0.915523886680603)
# - ('energy availability', 'Adaptation', 0.9047046303749084)
# - ('energy', 'Energy (general)', 0.8982304334640503)
# - ('energy distribution', 'Energy production', 0.8556111454963684)
# ----------------------
# To put that in real-world context, roughly 35 jobs are created for each million board feet of wood processed.
#
# INSTRUMENT PREDICTIONS
#
#
# SECTOR PREDICTIONS
#
# ----------------------
# Research on the likelihood of disasters and the assessment of the likely social, economic and environmental impacts will be conducted regularly as an integral aspect of disaster preparedness and management.
#
# INSTRUMENT PREDICTIONS
# - ('scientific inquiries', 'Knowledge generation', 0.9971142411231995)
# - ('assessment', 'Monitoring and evaluation', 0.9962424039840698)
# - ('research programme', 'Knowledge generation', 0.9916340708732605)
# - ('research body', 'Knowledge generation', 0.9879178404808044)
# - ('environmental assessment', 'Structures and processes', 0.9875245690345764)
# - ('risk assessments', 'Structures and processes', 0.9821717739105225)
# - ('research scheme', 'Knowledge generation', 0.9695672392845154)
# - ('climate risk', 'Monitoring and evaluation', 0.9624338746070862)
# - ('evaluation', 'Monitoring and evaluation', 0.9589711427688599)
# - ('monitoring', 'Monitoring and evaluation', 0.8838499784469604)
#
# SECTOR PREDICTIONS
# - ('disaster risk management', 'Disaster risk management', 0.9903572797775269)
# - ('vulnerability', 'Adaptation', 0.9838503003120422)
# - ('storm', 'Disaster risk management', 0.9290751814842224)
# - ('environment', 'Environment', 0.8832356929779053)
# - ('climate monitoring', 'Disaster risk management', 0.864292323589325)
# - ('hazard', 'Adaptation', 0.8019649386405945)
# ----------------------
# AEI10+A53: Mandatory blending of biofuels into mineral fuels.
#
# INSTRUMENT PREDICTIONS
# - ('product information', 'Labelling and information', 0.9951601028442383)
# - ('adaptation plan', 'Developing plans and stratgegies', 0.9763321280479431)
# - ('processes', 'Designing processes', 0.9762653708457947)
# - ('technical requirements', 'Obligations', 0.9709951281547546)
# - ('standards', 'Standards', 0.9240620136260986)
# - ('strategy', 'Developing plans and stratgegies', 0.8969429135322571)
# - ('reporting information', 'Knowledge sharing and dissemination', 0.8667895197868347)
# - ('information', 'Labelling and information', 0.8525539636611938)
# - ('assessment', 'Monitoring and evaluation', 0.8370506167411804)
# - ('reporting', 'Monitoring and evaluation', 0.8308606147766113)
#
# SECTOR PREDICTIONS
# - ('energy mix', 'Energy (general)', 0.999057948589325)
# - ('biofuels', 'Energy production', 0.9990378618240356)
# - ('fuels', 'Energy production', 0.9973153471946716)
# - ('biochar', 'Agriculture (general)', 0.9949648976325989)
# - ('mineral products', 'Industrial products', 0.9858006238937378)
# - ('fuel processing', 'Energy production', 0.98472660779953)
# - ('biodiesel', 'Energy production', 0.9392741918563843)
# - ('energy', 'Energy (general)', 0.8942879438400269)
# - ('adaptation', 'Adaptation', 0.8932548761367798)
# - ('non-residential buildings', 'Non-residential buildings', 0.8554782271385193)
# - ('fuel transformation', 'Energy production', 0.850045382976532)
# - ('ecosystem-based adaptation', 'Nature-based solutions', 0.8183144927024841)
# ----------------------
# Paragraph (4) of subsection (c) of such section is amended to read as follows: )
#
# INSTRUMENT PREDICTIONS
#
#
# SECTOR PREDICTIONS
#
# ----------------------
# 4702 PUBLIC LAW 110417OCT.
#
# INSTRUMENT PREDICTIONS
# - ('labelling', 'Labelling and information', 0.8623604774475098)
# - ('information', 'Labelling and information', 0.8321852684020996)
# - ('interest', 'Finance', 0.8164310455322266)
# - ('public information', 'Knowledge sharing and dissemination', 0.8094991445541382)
#
# SECTOR PREDICTIONS
# - ('public buildings', 'Non-residential buildings', 0.9702925086021423)
# - ('marine biodiversity', 'Coastal zones', 0.800459086894989)
# ----------------------
# Consult Repair Manual/Owners Guide Before Attempting To Service This Product.
#
# INSTRUMENT PREDICTIONS
# - ('reporting information', 'Knowledge sharing and dissemination', 0.9996388554573059)
# - ('advice', 'Knowledge sharing and dissemination', 0.9995498657226562)
# - ('product information', 'Labelling and information', 0.999467134475708)
# - ('consultation', 'Knowledge sharing and dissemination', 0.9988633990287781)
# - ('guideline', 'Standards', 0.9977498650550842)
# - ('information', 'Labelling and information', 0.9960888028144836)
# - ('reporting', 'Monitoring and evaluation', 0.9918580651283264)
# - ('guidelines', 'Designing processes', 0.9850326180458069)
# - ('technical assistance', 'Knowledge sharing and dissemination', 0.9661756157875061)
# - ('assessment', 'Monitoring and evaluation', 0.9474741220474243)
# - ('evaluation', 'Monitoring and evaluation', 0.9444618225097656)
# - ('amending target', 'Setting targets', 0.9121503829956055)
# - ('obligations', 'Obligations', 0.8018151521682739)
#
# SECTOR PREDICTIONS
# - ('tips', 'Waste', 0.9926227927207947)
# - ('adaptation consultation', 'Disaster risk management', 0.9695330262184143)
# - ('semi-detached house', 'Residential buildings', 0.8659747242927551)
# - ('non-residential buildings', 'Non-residential buildings', 0.8628557920455933)
# - ('residential buildings', 'Residential buildings', 0.8306934833526611)
# ----------------------
# See Chapter 11.
#
# INSTRUMENT PREDICTIONS
# - ('information', 'Labelling and information', 0.9559052586555481)
#
# SECTOR PREDICTIONS
# - ('residential buildings', 'Residential buildings', 0.819723904132843)
# - ('semi-detached house', 'Residential buildings', 0.8146635890007019)
# - ('detached house', 'Residential buildings', 0.8131712079048157)
# - ('marine biodiversity', 'Coastal zones', 0.8091747760772705)
# - ('green homes', 'Residential buildings', 0.8014116883277893)
# - ('energy efficiency', 'Energy use', 0.801233172416687)
# ----------------------
# Levelized costs for electricity generation technologies, 2000 2050 .
#
# INSTRUMENT PREDICTIONS
# - ('reporting', 'Monitoring and evaluation', 0.9968311190605164)
# - ('technology', 'Knowledge generation', 0.9949164390563965)
# - ('information', 'Labelling and information', 0.9759712219238281)
# - ('reporting information', 'Knowledge sharing and dissemination', 0.9693514704704285)
# - ('processes', 'Designing processes', 0.9610257744789124)
# - ('limit', 'Standards', 0.9479368925094604)
# - ('labelling', 'Labelling and information', 0.9195034503936768)
# - ('technical requirements', 'Obligations', 0.8729100823402405)
# - ('interest', 'Finance', 0.832197904586792)
# - ('assessment', 'Monitoring and evaluation', 0.8303830027580261)
#
# SECTOR PREDICTIONS
# - ('energy technology', 'Energy use', 0.9992128014564514)
# - ('electricity', 'Energy use', 0.9988368153572083)
# - ('electriciy charges', 'Energy use', 0.9973531365394592)
# - ('energy', 'Energy (general)', 0.9848403930664062)
# - ('power', 'Energy use', 0.9721218943595886)
# - ('energy use', 'Energy use', 0.9605240821838379)
# - ('energy production', 'Energy production', 0.9188457131385803)
# - ('non-residential buildings', 'Non-residential buildings', 0.8412984013557434)
# - ('power industry', 'Energy production', 0.8370649218559265)
# - ('semi-detached house', 'Residential buildings', 0.8232851028442383)
# - ('physical risk', 'Disaster risk management', 0.8193000555038452)
# - ('energy industries', 'Energy production', 0.8147101402282715)
# ----------------------
# fitting a curve to that data, can and should include some consideration of specific policy goals.
#
# INSTRUMENT PREDICTIONS
# - ('information', 'Labelling and information', 0.8787543177604675)
#
# SECTOR PREDICTIONS
#
# ----------------------
# The reforms we have made so far give Timor-Leste one of the most attractive taxation systems in the world for doing business.
#
# INSTRUMENT PREDICTIONS
# - ('tax system', 'Fiscal or financial incentives', 0.9997903108596802)
# - ('taxes', 'Fiscal or financial incentives', 0.9986674189567566)
# - ('tax advantages', 'Fiscal or financial incentives', 0.9907611012458801)
# - ('adaptation plan', 'Developing plans and stratgegies', 0.9704431295394897)
# - ('processes', 'Designing processes', 0.9560195207595825)
# - ('amending target', 'Setting targets', 0.8728563189506531)
# - ('organisation', 'Creating bodies/institutions', 0.8159526586532593)
#
# SECTOR PREDICTIONS
# - ('adaptation', 'Adaptation', 0.992092490196228)
# - ('rewetting', 'Land use', 0.8409963846206665)
# - ('treatment', 'Health', 0.8308264017105103)
# - ('resilience', 'Adaptation', 0.8103207945823669)
# ----------------------
# A central market infrastructure in Koror has become an issue of some urgency, especially given the inevitable increases in production resulting from the improved access to Babeldaob Island since the completion of the Compact Road.
#
# INSTRUMENT PREDICTIONS
# - ('infrastructure', 'Infrastructure', 0.9997292757034302)
# - ('interest', 'Finance', 0.9959540963172913)
#
# SECTOR PREDICTIONS
# - ('resilient infrastructure', 'Adaptation', 0.8076283931732178)
# ----------------------
# Encourage alternative transport modalities (such as cycling, car-pooling or car-sharing) through urban planning and the development of an appropriate infrastructure for cycling (bike lanes, storage racks, special subway and train wagons/compartments for bikes) and extension of pedestrian areas, especially in large urban aglomerations.
#
# INSTRUMENT PREDICTIONS
# - ('planning', 'Management and planning', 0.9997373819351196)
# - ('adaptation plan', 'Developing plans and stratgegies', 0.9996932148933411)
# - ('planning body', 'Creating bodies/institutions', 0.9992846250534058)
# - ('infrastructure', 'Infrastructure', 0.99811190366745)
# - ('plan', 'Developing plans and stratgegies', 0.9962988495826721)
# - ('strategy', 'Developing plans and stratgegies', 0.982992947101593)
# - ('spatial zoning', 'Management and planning', 0.9424058794975281)
# - ('guidelines', 'Designing processes', 0.9175938367843628)
# - ('interest', 'Finance', 0.9081353545188904)
# - ('strategic plan', 'Developing plans and stratgegies', 0.8951250314712524)
# - ('strategic body', 'Creating bodies/institutions', 0.8865336179733276)
# - ('organisation', 'Creating bodies/institutions', 0.8755207061767578)
# - ('resilient infrastructure policy', 'Standards', 0.8512319922447205)
# - ('advice', 'Knowledge sharing and dissemination', 0.8203640580177307)
# - ('structures', 'Structures and processes', 0.8124305605888367)
#
# SECTOR PREDICTIONS
# - ('transport infrastructure', 'Transport infrastructure', 0.999786376953125)
# - ('cycling infrastructure', 'Transport infrastructure', 0.9997212290763855)
# - ('urban infrastructure', 'Urban', 0.9996927976608276)
# - ('transport', 'Transport (general)', 0.9995393753051758)
# - ('cycling', 'Road transport', 0.9993312358856201)
# - ('adaptation', 'Adaptation', 0.9985800385475159)
# - ('treatment', 'Health', 0.9762297868728638)
# - ('road transport', 'Road transport', 0.974041759967804)
# - ('urban', 'Urban', 0.9335458278656006)
# - ('resilient infrastructure', 'Adaptation', 0.8612487316131592)
# - ('cities', 'Urban', 0.8587867617607117)
# - ('resilience', 'Adaptation', 0.8240035772323608)
# - ('refueeling infrastructure', 'Transport infrastructure', 0.8097264766693115)
# ----------------------
# The transaction costs and inefficiencies of seeking approval from the Centre for any changes are so high that most changes never get done and many budget lines remain unspent or under-spent.
#
# INSTRUMENT PREDICTIONS
#
#
# SECTOR PREDICTIONS
#
# ----------------------
# The Physical Planning Act, 2003.
#
# INSTRUMENT PREDICTIONS
# - ('planning', 'Management and planning', 0.9989147186279297)
# - ('planning body', 'Creating bodies/institutions', 0.9981396198272705)
# - ('plan', 'Developing plans and stratgegies', 0.851922333240509)
#
# SECTOR PREDICTIONS
# - ('resilient infrastructure', 'Adaptation', 0.874110221862793)
# - ('resilience', 'Adaptation', 0.8305424451828003)
# ----------------------
# To supplement the water available to farmers especially during the dry season the Agricultural Resource Management Project (ARMP) during the period 2011 2012 had undertaken the construction of water dams around the island of St. Kitts with three (3) completed and 1 under construction.
#
# INSTRUMENT PREDICTIONS
# - ('resource management', 'Structures and processes', 0.856448769569397)
#
# SECTOR PREDICTIONS
# - ('water availability', 'Adaptation', 0.9554471373558044)
# ----------------------
# Improving management of both protection and production forests for REDD-plus Managing lands for multiple uses requires active monitoring, clear regulations, impact assessments strong enforcement and collaboration among stakeholders.
#
# INSTRUMENT PREDICTIONS
# - ('monitoring', 'Monitoring and evaluation', 0.9990077018737793)
# - ('assessment', 'Monitoring and evaluation', 0.9980082511901855)
# - ('management', 'Management and planning', 0.9975667595863342)
# - ('environmental assessment', 'Structures and processes', 0.993363618850708)
# - ('resource management', 'Structures and processes', 0.9905040860176086)
# - ('evaluation', 'Monitoring and evaluation', 0.9757797718048096)
# - ('auditing', 'Monitoring and evaluation', 0.8972858786582947)
# - ('responsibility', 'Obligations', 0.8966096639633179)
# - ('target', 'Setting targets', 0.8194898366928101)
# - ('interest', 'Finance', 0.811536967754364)
# - ('information', 'Labelling and information', 0.8064722418785095)
# - ('processes', 'Designing processes', 0.8049779534339905)
#
# SECTOR PREDICTIONS
# - ('forests', 'Forestry', 0.9998054504394531)
# - ('forestry', 'Forestry', 0.9997096657752991)
# - ('forest management', 'Forestry', 0.9996932148933411)
# - ('land management', 'Land use', 0.9996483325958252)
# - ('logging', 'Forestry', 0.9995526671409607)
# - ('forest protection', 'Forestry', 0.999470055103302)
# - ('trees', 'Forestry', 0.9988754391670227)
# - ('environment', 'Environment', 0.9676342010498047)
# - ('ecosystem-based adaptation', 'Nature-based solutions', 0.9297633767127991)
# - ('ecological interactions', 'Land use', 0.8655948042869568)
# ----------------------
# The absence of effective data collection and evaluation mechanisms result in the inability of government to dynamically change course based on performance feedback.
#
# INSTRUMENT PREDICTIONS
# - ('limit', 'Standards', 0.9971292018890381)
# - ('evaluation', 'Monitoring and evaluation', 0.9629147052764893)
#
# SECTOR PREDICTIONS
# - ('degreasing', 'Industrial processes', 0.915747344493866)
# - ('onshore', 'Energy production', 0.8963587284088135)
# - ('afforestation', 'Forestry', 0.8085614442825317)
# ----------------------
# (b) WAIVERS OF TRAINING REQUIREMENTS.Section 231(c) of the Trade Act of 1974 (19 U.S.C. 2291(c) is amended (1) in paragraph (1)(B) (A) by striking The worker possesses and inserting the following: (i) IN GENERAL.The worker possesses.
#
# INSTRUMENT PREDICTIONS
# - ('amending target', 'Setting targets', 0.9992839694023132)
# - ('training', 'Knowledge sharing and dissemination', 0.986493706703186)
# - ('obligations', 'Obligations', 0.9777510762214661)
#
# SECTOR PREDICTIONS
#
# ----------------------
# based on the life cycle greenhouse gas emissions per unit of energy from fossil fuels in 2010 for the purposes of paragraph 2.
#
# INSTRUMENT PREDICTIONS
# - ('information', 'Labelling and information', 0.9825943112373352)
# - ('labelling', 'Labelling and information', 0.9716405272483826)
# - ('reporting information', 'Knowledge sharing and dissemination', 0.9394667744636536)
# - ('processes', 'Designing processes', 0.9250624775886536)
# - ('reporting', 'Monitoring and evaluation', 0.8357685208320618)
#
# SECTOR PREDICTIONS
# - ('fossil fuels', 'Energy production', 0.997497022151947)
# - ('energy', 'Energy (general)', 0.993479311466217)
# - ('fuels', 'Energy production', 0.9835011959075928)
# - ('gas', 'Energy production', 0.943642258644104)
# - ('climate-related perils', 'Disaster risk management', 0.9385194182395935)
# - ('cycling', 'Road transport', 0.9364647269248962)
# - ('energy combustion activities', 'Energy production', 0.8127855062484741)
# ----------------------
# The NCCC has roles and responsibilities to coordinate and cooperate with concerned ministries and institutions aiming to: - Review and approve workplans and reports of the Climate Change Technical Team (CCTT) to be established in accordance with Article 4 of this Sub-Decree. 1.
#
# INSTRUMENT PREDICTIONS
# - ('stakeholder engagement', 'Structures and processes', 0.998609721660614)
# - ('obligations', 'Obligations', 0.9638658165931702)
# - ('reporting information', 'Knowledge sharing and dissemination', 0.9632330536842346)
# - ('responsibility', 'Obligations', 0.944815993309021)
# - ('strategy', 'Developing plans and stratgegies', 0.9386742115020752)
# - ('regulatory body', 'Creating bodies/institutions', 0.9096632599830627)
# - ('duty to set target', 'Setting targets', 0.8999030590057373)
# - ('monitoring', 'Monitoring and evaluation', 0.890886664390564)
# - ('co-ordinating body', 'Creating bodies/institutions', 0.8630034923553467)
# - ('organisation', 'Creating bodies/institutions', 0.8398808836936951)
# - ('reporting', 'Monitoring and evaluation', 0.8275727033615112)
#
# SECTOR PREDICTIONS
# - ('climate monitoring', 'Disaster risk management', 0.9365093111991882)
# - ('residential buildings', 'Residential buildings', 0.8088304400444031)
# ----------------------
# The situation is rather more complicated for precipitation.
#
# INSTRUMENT PREDICTIONS
#
#
# SECTOR PREDICTIONS
# - ('climate-related perils', 'Disaster risk management', 0.9993930459022522)
# - ('precipitation', 'Adaptation', 0.9985928535461426)
# - ('extreme weather events', 'Disaster risk management', 0.8050522804260254)
# ----------------------
# Member States may agree on the statistical transfer of a specified amount of energy from renewable sources from one Member State to another Member State.
#
# INSTRUMENT PREDICTIONS
# - ('obligations', 'Obligations', 0.9691849946975708)
# - ('processes', 'Designing processes', 0.934313178062439)
# - ('labelling', 'Labelling and information', 0.8628414869308472)
# - ('insitutions', 'Creating bodies/institutions', 0.8069809079170227)
#
# SECTOR PREDICTIONS
# - ('energy', 'Energy (general)', 0.9995335340499878)
# - ('energy distribution', 'Energy production', 0.9986914396286011)
# - ('renewable energy', 'Energy production', 0.996395468711853)
# - ('energy use', 'Energy use', 0.9691132307052612)
# - ('power', 'Energy use', 0.903843343257904)
# - ('energy availability', 'Adaptation', 0.901865541934967)
# - ('electricity', 'Energy use', 0.8754886388778687)
# - ('energy production', 'Energy production', 0.8380876183509827)
# - ('renewables', 'Energy production', 0.8251048922538757)
# ----------------------
# - tax advantages deriving from the provisions governing works implemented to achieve energy savings, including those following on from the installation of renewables plants (Decree Law 201/2011).
#
# INSTRUMENT PREDICTIONS
# - ('tax advantages', 'Fiscal or financial incentives', 0.999855637550354)
# - ('tax system', 'Fiscal or financial incentives', 0.9997186660766602)
# - ('taxes', 'Fiscal or financial incentives', 0.9993784427642822)
# - ('insitutions', 'Creating bodies/institutions', 0.9967861771583557)
# - ('guidelines', 'Designing processes', 0.9524375796318054)
# - ('energy efficiency rating', 'Labelling and information', 0.9325212836265564)
# - ('fiscal incentives', 'Fiscal or financial incentives', 0.9140765070915222)
# - ('labelling', 'Labelling and information', 0.8982061147689819)
#
# SECTOR PREDICTIONS
# - ('renewable energy', 'Energy production', 0.9839121103286743)
# - ('energy efficiency', 'Energy use', 0.9787842035293579)
# - ('energy', 'Energy (general)', 0.9427517056465149)
# - ('energy use', 'Energy use', 0.8910992741584778)
# - ('energy performance', 'Energy use', 0.8765490651130676)
# - ('energy availability', 'Adaptation', 0.8510579466819763)
# - ('resilience', 'Adaptation', 0.8147753477096558)
# - ('renewables', 'Energy production', 0.8063123822212219)
# ----------------------
# The Austrian Strategy for Adaptation to Climate Change 119 Nr.
#
# INSTRUMENT PREDICTIONS
# - ('strategy', 'Developing plans and stratgegies', 0.9992283582687378)
# - ('adaptation plan', 'Developing plans and stratgegies', 0.9989396333694458)
# - ('labelling', 'Labelling and information', 0.998896062374115)
# - ('amending target', 'Setting targets', 0.9982547760009766)
# - ('strategic plan', 'Developing plans and stratgegies', 0.996839702129364)
# - ('plan', 'Developing plans and stratgegies', 0.9623112082481384)
# - ('strategic body', 'Creating bodies/institutions', 0.9361191987991333)
# - ('interest', 'Finance', 0.8914326429367065)
#
# SECTOR PREDICTIONS
# - ('adaptation', 'Adaptation', 0.9801585078239441)
# - ('climate forecasting', 'Disaster risk management', 0.956764817237854)
# ----------------------
# PA PES PLM PPP RCF REDD+ RTC SCAP
#
# INSTRUMENT PREDICTIONS
# - ('reporting', 'Monitoring and evaluation', 0.9478313326835632)
# - ('standards', 'Standards', 0.8923957943916321)
# - ('evaluation', 'Monitoring and evaluation', 0.8694831728935242)
# - ('reporting information', 'Knowledge sharing and dissemination', 0.862682580947876)
# - ('product information', 'Labelling and information', 0.8471082448959351)
# - ('financing structure', 'Fiscal or financial incentives', 0.8430660963058472)
# - ('assessment', 'Monitoring and evaluation', 0.8375445008277893)
# - ('codes', 'Standards', 0.8347484469413757)
# - ('funding', 'Finance', 0.8323464393615723)
# - ('information', 'Labelling and information', 0.8248041868209839)
# - ('packaging', 'Labelling and information', 0.8205769062042236)
#
# SECTOR PREDICTIONS
# - ('energy', 'Energy (general)', 0.8385974764823914)
# - ('charging infrastructure', 'Transport infrastructure', 0.8368072509765625)
# - ('residential buildings', 'Residential buildings', 0.8264074921607971)
# - ('vehicles', 'Transport (general)', 0.8247127532958984)
# - ('energy technology', 'Energy use', 0.8123545050621033)
# ----------------------
# The road runs parallel and occasionally adjacent- to the coast.
#
# INSTRUMENT PREDICTIONS
# - ('reporting', 'Monitoring and evaluation', 0.872150719165802)
# - ('interest', 'Finance', 0.8215604424476624)
#
# SECTOR PREDICTIONS
# - ('coasts', 'Coastal zones', 0.9988090991973877)
# - ('onshore', 'Energy production', 0.9858507513999939)
# - ('housing', 'Residential buildings', 0.9039698839187622)
# - ('tips', 'Waste', 0.8795543909072876)
# - ('residential buildings', 'Residential buildings', 0.8769145607948303)
# - ('homes', 'Residential buildings', 0.8599557280540466)
# - ('treatment', 'Health', 0.8405832648277283)
# - ('road infrasructure', 'Transport infrastructure', 0.8385699987411499)
# - ('green homes', 'Residential buildings', 0.8375572562217712)
# - ('navigation', 'Maritime transport', 0.8232499957084656)
# - ('silvopasture', 'Agriculture (general)', 0.8169043660163879)
# ----------------------
# The fuel consumption is 10-35 % lower than for a Diesel-only driven lorry.
#
# INSTRUMENT PREDICTIONS
#
#
# SECTOR PREDICTIONS
# - ('vehicle emissions', 'Transport (general)', 0.9970451593399048)
# - ('negative emissions', 'Industrial processes', 0.9847637414932251)
# - ('fuels', 'Energy production', 0.9766744375228882)
# - ('lorries', 'Road transport', 0.945328414440155)
# ----------------------
# Federal Register / Vol.
#
# INSTRUMENT PREDICTIONS
# - ('reporting information', 'Knowledge sharing and dissemination', 0.9783980846405029)
# - ('information', 'Labelling and information', 0.9530765414237976)
# - ('labelling', 'Labelling and information', 0.8421729803085327)
# - ('interest', 'Finance', 0.8402824997901917)
# - ('insitutions', 'Creating bodies/institutions', 0.8300040364265442)
#
# SECTOR PREDICTIONS
# - ('buildings', 'Buildings (general)', 0.9541962146759033)
# - ('residential buildings', 'Residential buildings', 0.9167261123657227)
# - ('non-residential buildings', 'Non-residential buildings', 0.8871062994003296)
# - ('afforestation', 'Forestry', 0.8585439920425415)
# - ('green homes', 'Residential buildings', 0.8436661958694458)
# - ('homes', 'Residential buildings', 0.8416016101837158)
# - ('semi-detached house', 'Residential buildings', 0.8366767168045044)
# - ('shipping', 'Maritime transport', 0.8287327289581299)
# - ('detached house', 'Residential buildings', 0.8236562609672546)
# - ('ruminants', 'Livestock', 0.8105102777481079)
# ----------------------
# No. 11507, Feb. 4, 1970, 35 F.R. 2573, which provided for prevention, control, and abatement of air pollution at Federal facilities, was superseded by Ex.
#
# INSTRUMENT PREDICTIONS
#
#
# SECTOR PREDICTIONS
#
# ----------------------
