# %% [markdown]
# # Cosine similarity between sentence vectors as a noisy label source
#
# At sentence level. Various `sentence-bert` models are available at https://www.sbert.net/docs/pretrained_models.html
#
# We try representations trained for different tasks:
#
# * **asymmetric semantic search**, where a short query is provided to try to retrieve a longer paragraph
# * **symmetric semantic search**, where a query is provided to try to retrieve a similar-sized phrase
#
# ## KD notes
#
# - it seems that symmetric is more effective than asymmetric
# - the symmetric model also seems to do a good job at *not* assigning a sentence an instrument/sector label when there is no relevant instrument/sector
# - I've left the thresholds intentionally low in the notebook so we can have a look at some False Negatives
# - it was much more effective to generate keyword vectors using `{KEYWORD} {SUBSECTOR}` rather than just keyword, due to some keywords being not so topic-specific

# %%
# !pip install sentence-transformers umap-learn seaborn "numpy<1.20"
# Out:
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# Requirement already satisfied: sentence-transformers in /Users/kalyan/Documents/CPR/policy-search/.venv/lib/python3.8/site-packages (2.0.0)
# Requirement already satisfied: umap-learn in /Users/kalyan/Documents/CPR/policy-search/.venv/lib/python3.8/site-packages (0.5.1)
# Collecting seaborn
#   Using cached seaborn-0.11.2-py3-none-any.whl (292 kB)
# Requirement already satisfied: numpy<1.20 in /Users/kalyan/Documents/CPR/policy-search/.venv/lib/python3.8/site-packages (1.19.5)
# Requirement already satisfied: transformers<5.0.0,>=4.6.0 in /Users/kalyan/Documents/CPR/policy-search/.venv/lib/python3.8/site-packages (from sentence-transformers) (4.6.1)
# Requirement already satisfied: scipy in /Users/kalyan/Documents/CPR/policy-search/.venv/lib/python3.8/site-packages (from sentence-transformers) (1.6.1)
# Requirement already satisfied: torchvision in /Users/kalyan/Documents/CPR/policy-search/.venv/lib/python3.8/site-packages (from sentence-transformers) (0.9.1)
# Requirement already satisfied: torch>=1.6.0 in /Users/kalyan/Documents/CPR/policy-search/.venv/lib/python3.8/site-packages (from sentence-transformers) (1.8.1)
# Requirement already satisfied: huggingface-hub in /Users/kalyan/Documents/CPR/policy-search/.venv/lib/python3.8/site-packages (from sentence-transformers) (0.0.8)
# Requirement already satisfied: nltk in /Users/kalyan/Documents/CPR/policy-search/.venv/lib/python3.8/site-packages (from sentence-transformers) (3.6.2)
# Requirement already satisfied: sentencepiece in /Users/kalyan/Documents/CPR/policy-search/.venv/lib/python3.8/site-packages (from sentence-transformers) (0.1.96)
# Requirement already satisfied: scikit-learn in /Users/kalyan/Documents/CPR/policy-search/.venv/lib/python3.8/site-packages (from sentence-transformers) (0.24.2)
# Requirement already satisfied: tqdm in /Users/kalyan/Documents/CPR/policy-search/.venv/lib/python3.8/site-packages (from sentence-transformers) (4.62.3)
# Requirement already satisfied: pynndescent>=0.5 in /Users/kalyan/Documents/CPR/policy-search/.venv/lib/python3.8/site-packages (from umap-learn) (0.5.4)
# Requirement already satisfied: numba>=0.49 in /Users/kalyan/Documents/CPR/policy-search/.venv/lib/python3.8/site-packages (from umap-learn) (0.54.0)
# Collecting matplotlib>=2.2
#   Downloading matplotlib-3.4.3-cp38-cp38-macosx_10_9_x86_64.whl (7.2 MB)
#      |████████████████████████████████| 7.2 MB 7.2 MB/s eta 0:00:01
# Requirement already satisfied: pandas>=0.23 in /Users/kalyan/Documents/CPR/policy-search/.venv/lib/python3.8/site-packages (from seaborn) (1.3.3)
# Requirement already satisfied: pillow>=6.2.0 in /Users/kalyan/Documents/CPR/policy-search/.venv/lib/python3.8/site-packages (from matplotlib>=2.2->seaborn) (8.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/kalyan/Documents/CPR/policy-search/.venv/lib/python3.8/site-packages (from matplotlib>=2.2->seaborn) (2.8.2)
# Collecting kiwisolver>=1.0.1
#   Downloading kiwisolver-1.3.2-cp38-cp38-macosx_10_9_x86_64.whl (61 kB)
#      |████████████████████████████████| 61 kB 1.5 MB/s  eta 0:00:01
# Collecting cycler>=0.10
#   Using cached cycler-0.10.0-py2.py3-none-any.whl (6.5 kB)
# Requirement already satisfied: pyparsing>=2.2.1 in /Users/kalyan/Documents/CPR/policy-search/.venv/lib/python3.8/site-packages (from matplotlib>=2.2->seaborn) (2.4.7)
# Requirement already satisfied: six in /Users/kalyan/Documents/CPR/policy-search/.venv/lib/python3.8/site-packages (from cycler>=0.10->matplotlib>=2.2->seaborn) (1.16.0)
# Requirement already satisfied: setuptools in /Users/kalyan/Documents/CPR/policy-search/.venv/lib/python3.8/site-packages (from numba>=0.49->umap-learn) (57.4.0)
# Requirement already satisfied: llvmlite<0.38,>=0.37.0rc1 in /Users/kalyan/Documents/CPR/policy-search/.venv/lib/python3.8/site-packages (from numba>=0.49->umap-learn) (0.37.0)
# Requirement already satisfied: pytz>=2017.3 in /Users/kalyan/Documents/CPR/policy-search/.venv/lib/python3.8/site-packages (from pandas>=0.23->seaborn) (2021.3)
# Requirement already satisfied: joblib>=0.11 in /Users/kalyan/Documents/CPR/policy-search/.venv/lib/python3.8/site-packages (from pynndescent>=0.5->umap-learn) (1.0.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Users/kalyan/Documents/CPR/policy-search/.venv/lib/python3.8/site-packages (from scikit-learn->sentence-transformers) (2.2.0)
# Requirement already satisfied: typing-extensions in /Users/kalyan/Documents/CPR/policy-search/.venv/lib/python3.8/site-packages (from torch>=1.6.0->sentence-transformers) (3.10.0.2)
# Requirement already satisfied: filelock in /Users/kalyan/Documents/CPR/policy-search/.venv/lib/python3.8/site-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers) (3.0.12)
# Requirement already satisfied: packaging in /Users/kalyan/Documents/CPR/policy-search/.venv/lib/python3.8/site-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers) (21.0)
# Requirement already satisfied: sacremoses in /Users/kalyan/Documents/CPR/policy-search/.venv/lib/python3.8/site-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers) (0.0.45)
# Requirement already satisfied: requests in /Users/kalyan/Documents/CPR/policy-search/.venv/lib/python3.8/site-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers) (2.26.0)
# Requirement already satisfied: regex!=2019.12.17 in /Users/kalyan/Documents/CPR/policy-search/.venv/lib/python3.8/site-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers) (2021.8.28)
# Requirement already satisfied: tokenizers<0.11,>=0.10.1 in /Users/kalyan/Documents/CPR/policy-search/.venv/lib/python3.8/site-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers) (0.10.3)
# Requirement already satisfied: click in /Users/kalyan/Documents/CPR/policy-search/.venv/lib/python3.8/site-packages (from nltk->sentence-transformers) (8.0.1)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/kalyan/Documents/CPR/policy-search/.venv/lib/python3.8/site-packages (from requests->transformers<5.0.0,>=4.6.0->sentence-transformers) (2021.5.30)
# Requirement already satisfied: idna<4,>=2.5 in /Users/kalyan/Documents/CPR/policy-search/.venv/lib/python3.8/site-packages (from requests->transformers<5.0.0,>=4.6.0->sentence-transformers) (3.2)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/kalyan/Documents/CPR/policy-search/.venv/lib/python3.8/site-packages (from requests->transformers<5.0.0,>=4.6.0->sentence-transformers) (1.26.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /Users/kalyan/Documents/CPR/policy-search/.venv/lib/python3.8/site-packages (from requests->transformers<5.0.0,>=4.6.0->sentence-transformers) (2.0.6)
# Installing collected packages: kiwisolver, cycler, matplotlib, seaborn
# Successfully installed cycler-0.10.0 kiwisolver-1.3.2 matplotlib-3.4.3 seaborn-0.11.2

# %%
from pathlib import Path
from typing import List, Callable

from sentence_transformers import SentenceTransformer
from sentence_transformers import util as sbert_utils
import umap
from tqdm.auto import tqdm
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import torch

from utils import Schema, load_policy_dataset

# %%
df = load_policy_dataset()

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1666918 entries, 0 to 1666917
# Data columns (total 4 columns):
#  #   Column       Non-Null Count    Dtype
# ---  ------       --------------    -----
#  0   policy_id    1666918 non-null  int64
#  1   policy_name  1666918 non-null  object
#  2   page_id      1666918 non-null  int64
#  3   text         1666918 non-null  object
# dtypes: int64(2), object(2)
# memory usage: 50.9+ MB

# %%
SCHEMA_FOLDER = Path("../../schema")

instruments = Schema.from_yaml_path(SCHEMA_FOLDER/"instruments.yml")
sectors = Schema.from_yaml_path(SCHEMA_FOLDER/"sectors.yml")

# %% [markdown]
# ## 1. Different model types

# %%
def plot_projections(emb_2d: np.ndarray, schema: Schema, start_end: List[int] = None):
    twod_df = pd.DataFrame(emb_2d, columns=["x", "y"])
    twod_df['keyword'] = schema.all_keywords
    twod_df['subsector'] = twod_df['keyword'].map(schema.keyword_subsector_mapping)
    
    if start_end:
        twod_df = twod_df.sort_values('subsector', ascending=True).iloc[start_end[0], start_end[1]]

    _, ax = plt.subplots(figsize=(20,15))
    sns.scatterplot(x=twod_df["x"], y=twod_df["y"], hue=twod_df["subsector"], markers=".")

# plotting the projections doesn't seem to expose any particularly useful structure but the code is here just in case!
# reducer = umap.UMAP()
# sector_keyword_embeddings_2d = reducer.fit_transform(sector_keyword_embeddings)

# plot_projections(sector_keyword_embeddings_2d, sectors)

# %%
class CosineDistanceClassifier:
    def __init__(self, schema: Schema, sbert_model: str, distance_measure: str, concat_keywords_with_subsectors: bool):
        assert distance_measure in ['dot_product', 'cosine']
        
        self._normalise_vectors = distance_measure == 'dot_product'
        
        self.schema = schema
        self._keyword_subsector_mapping = self.schema.keyword_subsector_mapping
        
        self.sbert_model = sbert_model
        self.distance_measure = distance_measure
        
        self.encoder = self._get_sentence_encoder()
        self._keyword_embeddings = self._embed_keywords(concat_keywords_with_subsectors)
        
    def _get_sentence_encoder(self):
        return SentenceTransformer(self.sbert_model)
    
    def _keyword_subsector_concatenator(self, kwd: str):
        """string modifier for _embed_keywords"""
        
        return f"{kwd} {self._keyword_subsector_mapping[kwd]}"
    
    def _embed_keywords(self, concat_with_subsectors: bool):
        keywords = self.schema.all_keywords
        
        if concat_with_subsectors: 
            keywords = [self._keyword_subsector_concatenator(k) for k in keywords]
            
        keyword_embeddings = self.encoder.encode(keywords, convert_to_tensor=True)
        
        if self._normalise_vectors:
            keyword_embeddings = torch.nn.functional.normalize(keyword_embeddings, p=2, dim=1)
            
        return keyword_embeddings
            
    def predict(self, query: str, threshold: float):
        query_embedding = self.encoder.encode(query, convert_to_tensor=True)
        if self._normalise_vectors:
            query_embedding = torch.nn.functional.normalize(query_embedding, p=2, dim=0)
        
        cos_scores = sbert_utils.cos_sim(query_embedding, self._keyword_embeddings)[0]
        scores_above_threshold_idxs = torch.where(cos_scores >= threshold)[0]
        
        results = []
        
        for idx in scores_above_threshold_idxs:
            _keyword = self.schema.all_keywords[idx]
            _subsector = self._keyword_subsector_mapping[_keyword]
            _score = cos_scores[idx]
            
            results.append(
                (_keyword, _subsector, round(_score.item(), 4))
            )
            
        results.sort(key=lambda x: x[2], reverse=True)
        
        return results

# %%
# Prepare fixed number of examples; set parameters for the rest of this section

n_examples = 30
examples = df.sample(n_examples, random_state=99)['text'].tolist()

# %% [markdown]
# ### 1a) Asymmetric semantic search

# %%
"""
Model choices (from https://www.sbert.net/docs/pretrained-models/msmarco-v3.html):
- msmarco-MiniLM-L-6-v3: tuned for cosine similarity, which prefers retrieving shorter passages
- msmarco-distilbert-base-v4: same, but larger
- msmarco-distilbert-base-tas-b: tuned for dot product, which prefers retrieval of longer passages
"""

clf_instruments_asymm_cosine = CosineDistanceClassifier(
    schema = instruments, 
    sbert_model = "msmarco-MiniLM-L-6-v3", 
    distance_measure= "cosine",
    concat_keywords_with_subsectors= True,
)

clf_sectors_asymm_cosine = CosineDistanceClassifier(
    schema = sectors, 
    sbert_model = "msmarco-MiniLM-L-6-v3", 
    distance_measure= "cosine",
    concat_keywords_with_subsectors= True,
)

# %%
THRESHOLD = 0.35

for _str in examples:
    print(_str)
    print()
    print("INSTRUMENT PREDICTIONS")
    print("\n".join([f"- {pred}" for pred in clf_instruments_asymm_cosine.predict(_str, THRESHOLD)]))
    print()
    print("SECTOR PREDICTIONS")
    print("\n".join([f"- {pred}" for pred in clf_sectors_asymm_cosine.predict(_str, THRESHOLD)]))
    print("----------------------")
# Out:
# Sources of Energy Supply At present, Bangladesh has energy supply from both renewable and nonrenewable sources, 38 percent of which comes from biomass (Figure 3.1).
#
# INSTRUMENT PREDICTIONS
# - ('fossil fuel subsidy', 'Fiscal or financial incentives', 0.4097)
# - ('tariff', 'Fiscal or financial incentives', 0.3522)
#
# SECTOR PREDICTIONS
# - ('fossil fuels', 'Energy production', 0.4043)
# - ('fossil fuel fires', 'Energy production', 0.38)
# - ('electricity subsidies', 'Energy use', 0.3708)
# - ('renewable energy', 'Energy production', 0.3685)
# - ('solar energy', 'Energy production', 0.362)
# - ('forest tundra', 'Forestry', 0.3572)
# - ('energy technology', 'Energy use', 0.3555)
# ----------------------
# To put that in real-world context, roughly 35 jobs are created for each million board feet of wood processed.
#
# INSTRUMENT PREDICTIONS
#
#
# SECTOR PREDICTIONS
#
# ----------------------
# Research on the likelihood of disasters and the assessment of the likely social, economic and environmental impacts will be conducted regularly as an integral aspect of disaster preparedness and management.
#
# INSTRUMENT PREDICTIONS
# - ('environmental assessment', 'Structures and processes', 0.5205)
# - ('climate risk', 'Monitoring and evaluation', 0.4158)
# - ('reporting', 'Monitoring and evaluation', 0.4054)
# - ('risk assessments', 'Structures and processes', 0.4006)
# - ('carbon budget', 'Designing processes', 0.38)
# - ('assessment', 'Monitoring and evaluation', 0.3661)
# - ('risk screening', 'Monitoring and evaluation', 0.3658)
# - ('resilience funding', 'Infrastructure', 0.3523)
# - ('planning', 'Management and planning', 0.3504)
#
# SECTOR PREDICTIONS
# - ('climate forecasting', 'Disaster risk management', 0.4915)
# - ('climate monitoring', 'Disaster risk management', 0.4646)
# - ('adaptation consultation', 'Disaster risk management', 0.4526)
# - ('biodiversity', 'Environment', 0.4484)
# - ('hurricane', 'Disaster risk management', 0.4366)
# - ('storm', 'Disaster risk management', 0.4359)
# - ('disaster risk management', 'Disaster risk management', 0.4281)
# - ('flooding', 'Disaster risk management', 0.4217)
# - ('climate-related perils', 'Disaster risk management', 0.4098)
# - ('infrastructure damage', 'Adaptation', 0.4057)
# - ('natural disaster', 'Disaster risk management', 0.395)
# - ('precipitation', 'Adaptation', 0.3872)
# - ('avalanche', 'Disaster risk management', 0.3857)
# - ('insurance', 'Disaster risk management', 0.3725)
# - ('urban green infrastructure', 'Nature-based solutions', 0.3664)
# - ('wildfire', 'Disaster risk management', 0.3657)
# - ('ecosystem-based adaptation', 'Nature-based solutions', 0.3643)
# - ('ecological interactions', 'Land use', 0.3638)
# - ('early warning system', 'Disaster risk management', 0.3619)
# - ('resilient infrastructure', 'Adaptation', 0.3616)
# - ('urban forestry', 'Nature-based solutions', 0.3598)
# - ('cyclone', 'Disaster risk management', 0.3553)
# - ('physical risk', 'Disaster risk management', 0.3531)
# - ('typhoon', 'Disaster risk management', 0.3516)
# ----------------------
# AEI10+A53: Mandatory blending of biofuels into mineral fuels.
#
# INSTRUMENT PREDICTIONS
#
#
# SECTOR PREDICTIONS
# - ('biofuels', 'Energy production', 0.4998)
# - ('biodiesel', 'Energy production', 0.4142)
# - ('fuel exploitation', 'Energy production', 0.3904)
# - ('oil refinery', 'Energy production', 0.3789)
# - ('oil extraction', 'Energy production', 0.367)
# - ('energy mix', 'Energy (general)', 0.3668)
# - ('anhydrous ammonia', 'Industrial products', 0.3566)
# - ('fugitive emissions from fuels', 'Energy production', 0.3536)
# ----------------------
# Paragraph (4) of subsection (c) of such section is amended to read as follows: )
#
# INSTRUMENT PREDICTIONS
#
#
# SECTOR PREDICTIONS
#
# ----------------------
# 4702 PUBLIC LAW 110417OCT.
#
# INSTRUMENT PREDICTIONS
#
#
# SECTOR PREDICTIONS
#
# ----------------------
# Consult Repair Manual/Owners Guide Before Attempting To Service This Product.
#
# INSTRUMENT PREDICTIONS
#
#
# SECTOR PREDICTIONS
#
# ----------------------
# See Chapter 11.
#
# INSTRUMENT PREDICTIONS
#
#
# SECTOR PREDICTIONS
#
# ----------------------
# Levelized costs for electricity generation technologies, 2000 2050 .
#
# INSTRUMENT PREDICTIONS
# - ('technology', 'Knowledge generation', 0.3606)
# - ('energy efficiency rating', 'Labelling and information', 0.3503)
#
# SECTOR PREDICTIONS
# - ('electriciy charges', 'Energy use', 0.4187)
# - ('low-carbon technology', 'Energy production', 0.4177)
# - ('electricity', 'Energy use', 0.4132)
# - ('electricity distribution', 'Energy use', 0.4039)
# - ('grid modernisation', 'Energy use', 0.3989)
# - ('renewable energy', 'Energy production', 0.3977)
# - ('energy efficiency', 'Energy use', 0.3886)
# - ('energy technology', 'Energy use', 0.379)
# - ('electricity subsidies', 'Energy use', 0.3775)
# - ('renewables', 'Energy production', 0.3761)
# - ('high-carbon', 'Energy (general)', 0.3702)
# - ('industrial carbon dioxide', 'Industrial greenhouse gas emissions', 0.3684)
# - ('hydrogen transportation', 'Energy production', 0.3683)
# - ('industrial greenhouse gas emissions', 'Industrial greenhouse gas emissions', 0.3662)
# - ('geothermal energy', 'Energy production', 0.3642)
# - ('nuclear energy', 'Energy production', 0.3606)
# - ('solar energy', 'Energy production', 0.3584)
# - ('hydropower', 'Energy production', 0.3569)
# - ('energy demand', 'Energy production', 0.3525)
# ----------------------
# fitting a curve to that data, can and should include some consideration of specific policy goals.
#
# INSTRUMENT PREDICTIONS
# - ('zoning', 'Management and planning', 0.3539)
#
# SECTOR PREDICTIONS
#
# ----------------------
# The reforms we have made so far give Timor-Leste one of the most attractive taxation systems in the world for doing business.
#
# INSTRUMENT PREDICTIONS
# - ('tax relief', 'Fiscal or financial incentives', 0.3877)
# - ('tax system', 'Fiscal or financial incentives', 0.36)
#
# SECTOR PREDICTIONS
#
# ----------------------
# A central market infrastructure in Koror has become an issue of some urgency, especially given the inevitable increases in production resulting from the improved access to Babeldaob Island since the completion of the Compact Road.
#
# INSTRUMENT PREDICTIONS
# - ('procurement', 'Infrastructure', 0.4285)
# - ('infrastructure', 'Infrastructure', 0.4222)
# - ('public infrastructure', 'Infrastructure', 0.4086)
# - ('investment', 'Infrastructure', 0.4077)
# - ('public spending', 'Infrastructure', 0.3888)
# - ('resilience funding', 'Infrastructure', 0.3694)
#
# SECTOR PREDICTIONS
# - ('airport infrastructure', 'Transport infrastructure', 0.4262)
# - ('transport infrastructure', 'Transport infrastructure', 0.4152)
# - ('public transport', 'Transport infrastructure', 0.4079)
# - ('cycling infrastructure', 'Transport infrastructure', 0.3778)
# - ('urban infrastructure', 'Urban', 0.3603)
# - ('infrastructure damage', 'Adaptation', 0.3581)
# ----------------------
# Encourage alternative transport modalities (such as cycling, car-pooling or car-sharing) through urban planning and the development of an appropriate infrastructure for cycling (bike lanes, storage racks, special subway and train wagons/compartments for bikes) and extension of pedestrian areas, especially in large urban aglomerations.
#
# INSTRUMENT PREDICTIONS
# - ('investment', 'Infrastructure', 0.3663)
#
# SECTOR PREDICTIONS
# - ('cycling infrastructure', 'Transport infrastructure', 0.5106)
# - ('cycling', 'Road transport', 0.4759)
# - ('electric cars', 'Road transport', 0.3807)
# - ('urban infrastructure', 'Urban', 0.3806)
# - ('resilient infrastructure', 'Adaptation', 0.3799)
# - ('cars', 'Road transport', 0.3757)
# - ('rail transport', 'Rail transport', 0.3645)
# - ('urban green infrastructure', 'Nature-based solutions', 0.3618)
# ----------------------
# The transaction costs and inefficiencies of seeking approval from the Centre for any changes are so high that most changes never get done and many budget lines remain unspent or under-spent.
#
# INSTRUMENT PREDICTIONS
# - ('carbon budget', 'Designing processes', 0.3796)
#
# SECTOR PREDICTIONS
#
# ----------------------
# The Physical Planning Act, 2003.
#
# INSTRUMENT PREDICTIONS
# - ('planning', 'Management and planning', 0.357)
#
# SECTOR PREDICTIONS
#
# ----------------------
# To supplement the water available to farmers especially during the dry season the Agricultural Resource Management Project (ARMP) during the period 2011 2012 had undertaken the construction of water dams around the island of St. Kitts with three (3) completed and 1 under construction.
#
# INSTRUMENT PREDICTIONS
# - ('adaptation plan', 'Developing plans and stratgegies', 0.4001)
# - ('federal adaptation programme', 'Structures and processes', 0.3808)
#
# SECTOR PREDICTIONS
# - ('water stress', 'Adaptation', 0.4381)
# - ('flooding', 'Disaster risk management', 0.4302)
# - ('water availability', 'Adaptation', 0.4168)
# - ('saltwater intrusion', 'Adaptation', 0.4149)
# - ('farm irrigation', 'Agriculture (general)', 0.4143)
# - ('agricultural infrastructure', 'Agriculture (general)', 0.4081)
# - ('adaptation consultation', 'Disaster risk management', 0.4049)
# - ('irrigation', 'Agriculture (general)', 0.3973)
# - ('infrastructure damage', 'Adaptation', 0.3918)
# - ('precipitation', 'Adaptation', 0.3868)
# - ('land management', 'Land use', 0.3865)
# - ('ecological interactions', 'Land use', 0.3729)
# - ('pest regulation', 'Agriculture (general)', 0.3712)
# - ('tuber', 'Agricultural produce', 0.3699)
# - ('rice cultivation', 'Agricultural produce', 0.3685)
# - ('forest management', 'Forestry', 0.3587)
# - ('soil degradation', 'Adaptation', 0.3574)
# - ('storm', 'Disaster risk management', 0.3516)
# - ('agricultural waste burning', 'Agriculture (general)', 0.351)
# ----------------------
# Improving management of both protection and production forests for REDD-plus Managing lands for multiple uses requires active monitoring, clear regulations, impact assessments strong enforcement and collaboration among stakeholders.
#
# INSTRUMENT PREDICTIONS
# - ('research and development', 'Knowledge generation', 0.3862)
#
# SECTOR PREDICTIONS
# - ('forest management', 'Forestry', 0.5715)
# - ('forests', 'Forestry', 0.5384)
# - ('forest protection', 'Forestry', 0.5381)
# - ('forest restoration', 'Forestry', 0.4935)
# - ('forest rehabilitation', 'Forestry', 0.484)
# - ('forest conversion', 'Forestry', 0.4832)
# - ('forestry', 'Forestry', 0.4711)
# - ('natural forest', 'Forestry', 0.4692)
# - ('trees', 'Forestry', 0.4662)
# - ('temperate forest', 'Forestry', 0.4639)
# - ('logging', 'Forestry', 0.4566)
# - ('urban forestry', 'Nature-based solutions', 0.4525)
# - ('forest onservation', 'Forestry', 0.4466)
# - ('boreal forest', 'Forestry', 0.4277)
# - ('afforestation', 'Forestry', 0.4261)
# - ('land management', 'Land use', 0.4226)
# - ('deforestation', 'Forestry', 0.4219)
# - ('tropical forest', 'Forestry', 0.4193)
# - ('biodiversity', 'Environment', 0.3922)
# - ('green infrastructure', 'Nature-based solutions', 0.3874)
# - ('forest tundra', 'Forestry', 0.3775)
# - ('land degradation', 'Land use', 0.3767)
# - ('agricultural productivity', 'Agriculture (general)', 0.3663)
# - ('green space management', 'Nature-based solutions', 0.3655)
# - ('wetlands', 'Land use', 0.3602)
# - ('soil degradation', 'Adaptation', 0.3592)
# - ('infrastructure damage', 'Adaptation', 0.3577)
# - ('oil well development', 'Energy production', 0.3575)
# - ('coastal erosion', 'Adaptation', 0.3554)
# ----------------------
# The absence of effective data collection and evaluation mechanisms result in the inability of government to dynamically change course based on performance feedback.
#
# INSTRUMENT PREDICTIONS
# - ('site selection', 'Monitoring and evaluation', 0.3975)
# - ('processes', 'Designing processes', 0.3907)
# - ('reporting', 'Monitoring and evaluation', 0.3874)
# - ('guidelines', 'Designing processes', 0.386)
# - ('environmental assessment', 'Structures and processes', 0.3808)
# - ('protocol', 'Designing processes', 0.3649)
# - ('assessment', 'Monitoring and evaluation', 0.3637)
# - ('auditing', 'Monitoring and evaluation', 0.3603)
# - ('national adaptation service', 'Structures and processes', 0.3571)
#
# SECTOR PREDICTIONS
# - ('adaptation consultation', 'Disaster risk management', 0.3842)
# - ('resilience', 'Adaptation', 0.3521)
# ----------------------
# (b) WAIVERS OF TRAINING REQUIREMENTS.Section 231(c) of the Trade Act of 1974 (19 U.S.C. 2291(c) is amended (1) in paragraph (1)(B) (A) by striking The worker possesses and inserting the following: (i) IN GENERAL.The worker possesses.
#
# INSTRUMENT PREDICTIONS
# - ('technical requirements', 'Obligations', 0.4184)
# - ('mandates', 'Obligations', 0.408)
#
# SECTOR PREDICTIONS
#
# ----------------------
# based on the life cycle greenhouse gas emissions per unit of energy from fossil fuels in 2010 for the purposes of paragraph 2.
#
# INSTRUMENT PREDICTIONS
# - ('energy efficiency rating', 'Labelling and information', 0.3576)
#
# SECTOR PREDICTIONS
# - ('agricultural greenhouse gas emissions', 'Agricultural greenhouse gas emissions', 0.5524)
# - ('industrial greenhouse gas emissions', 'Industrial greenhouse gas emissions', 0.5493)
# - ('fossil fuels', 'Energy production', 0.5318)
# - ('agricultural carbon dioxide', 'Agricultural greenhouse gas emissions', 0.5287)
# - ('industrial nitrous oxide', 'Industrial greenhouse gas emissions', 0.5084)
# - ('agricultural nitrous oxide', 'Agricultural greenhouse gas emissions', 0.5061)
# - ('agricultural methane', 'Agricultural greenhouse gas emissions', 0.5016)
# - ('fugitive emissions from fuels', 'Energy production', 0.4987)
# - ('industrial carbon dioxide', 'Industrial greenhouse gas emissions', 0.4986)
# - ('fossil fuel fires', 'Energy production', 0.4689)
# - ('fuels', 'Energy production', 0.4656)
# - ('energy efficiency', 'Energy use', 0.4489)
# - ('solid fuels', 'Energy production', 0.4486)
# - ('energy combustion activities', 'Energy production', 0.4466)
# - ('energy', 'Energy (general)', 0.4451)
# - ('fossil fuel phase-out', 'Energy production', 0.4368)
# - ('fuel transformation', 'Energy production', 0.429)
# - ('biodiesel', 'Energy production', 0.4185)
# - ('energy research', 'Energy (general)', 0.4178)
# - ('high-carbon', 'Energy (general)', 0.4118)
# - ('vehicle emissions', 'Transport (general)', 0.4114)
# - ('low-carbon', 'Energy (general)', 0.4094)
# - ('energy use', 'Energy use', 0.4082)
# - ('energy mix', 'Energy (general)', 0.4054)
# - ('combustion', 'Energy production', 0.4009)
# - ('natural gas', 'Energy production', 0.4001)
# - ('energy storage', 'Energy use', 0.3986)
# - ('energy performance', 'Energy use', 0.3928)
# - ('energy technology', 'Energy use', 0.3923)
# - ('electricity', 'Energy use', 0.3902)
# - ('renewable energy', 'Energy production', 0.3885)
# - ('biofuels', 'Energy production', 0.3881)
# - ('grid modernisation', 'Energy use', 0.3803)
# - ('bioethanol', 'Energy production', 0.3763)
# - ('geothermal energy', 'Energy production', 0.3733)
# - ('fuel exploitation', 'Energy production', 0.3709)
# - ('gas', 'Energy production', 0.3683)
# - ('carbon capture', 'Energy (general)', 0.3651)
# - ('petroleum', 'Energy production', 0.3639)
# - ('bioenergy', 'Energy production', 0.3616)
# - ('fuel processing', 'Energy production', 0.3597)
# - ('solar energy', 'Energy production', 0.357)
# - ('nuclear energy', 'Energy production', 0.3539)
# - ('energy industries', 'Energy production', 0.3536)
# - ('electricity distribution', 'Energy use', 0.3533)
# - ('heating', 'Energy use', 0.352)
# - ('coal', 'Energy production', 0.3504)
# ----------------------
# The NCCC has roles and responsibilities to coordinate and cooperate with concerned ministries and institutions aiming to: - Review and approve workplans and reports of the Climate Change Technical Team (CCTT) to be established in accordance with Article 4 of this Sub-Decree. 1.
#
# INSTRUMENT PREDICTIONS
# - ('carbon budget', 'Designing processes', 0.3529)
#
# SECTOR PREDICTIONS
#
# ----------------------
# The situation is rather more complicated for precipitation.
#
# INSTRUMENT PREDICTIONS
#
#
# SECTOR PREDICTIONS
# - ('precipitation', 'Adaptation', 0.4382)
# - ('climate-related perils', 'Disaster risk management', 0.4313)
# - ('climate forecasting', 'Disaster risk management', 0.3906)
# ----------------------
# Member States may agree on the statistical transfer of a specified amount of energy from renewable sources from one Member State to another Member State.
#
# INSTRUMENT PREDICTIONS
#
#
# SECTOR PREDICTIONS
#
# ----------------------
# - tax advantages deriving from the provisions governing works implemented to achieve energy savings, including those following on from the installation of renewables plants (Decree Law 201/2011).
#
# INSTRUMENT PREDICTIONS
# - ('tax advantages', 'Fiscal or financial incentives', 0.5502)
# - ('tax relief', 'Fiscal or financial incentives', 0.3781)
# - ('energy efficiency rating', 'Labelling and information', 0.3776)
#
# SECTOR PREDICTIONS
# - ('electricity subsidies', 'Energy use', 0.4481)
# - ('renewables', 'Energy production', 0.4212)
# - ('energy efficiency', 'Energy use', 0.419)
# - ('renewable energy', 'Energy production', 0.4112)
# - ('electricity', 'Energy use', 0.3942)
# ----------------------
# The Austrian Strategy for Adaptation to Climate Change 119 Nr.
#
# INSTRUMENT PREDICTIONS
# - ('equity in adaptation', 'Standards', 0.5118)
# - ('adaptation plan', 'Developing plans and stratgegies', 0.4632)
# - ('national adaptation service', 'Structures and processes', 0.4561)
# - ('federal adaptation programme', 'Structures and processes', 0.4219)
# - ('resilient infrastructure policy', 'Standards', 0.4092)
# - ('climate vulnerabiliy', 'Monitoring and evaluation', 0.3956)
# - ('climate risk', 'Monitoring and evaluation', 0.3839)
#
# SECTOR PREDICTIONS
# - ('temperature variability', 'Adaptation', 0.5724)
# - ('wind patterns', 'Adaptation', 0.5529)
# - ('ecosystem-based adaptation', 'Nature-based solutions', 0.5489)
# - ('adaptation', 'Adaptation', 0.5313)
# - ('resilient infrastructure', 'Adaptation', 0.5196)
# - ('erosion', 'Adaptation', 0.5161)
# - ('coastal erosion', 'Adaptation', 0.5112)
# - ('resilience', 'Adaptation', 0.504)
# - ('vulnerability', 'Adaptation', 0.5005)
# - ('cold wave', 'Adaptation', 0.4938)
# - ('adaptation consultation', 'Disaster risk management', 0.492)
# - ('desertification', 'Adaptation', 0.48)
# - ('energy availability', 'Adaptation', 0.4723)
# - ('precipitation', 'Adaptation', 0.469)
# - ('infrastructure damage', 'Adaptation', 0.4463)
# - ('hazard', 'Adaptation', 0.4357)
# - ('ocean acidification', 'Adaptation', 0.4282)
# - ('frost', 'Adaptation', 0.425)
# - ('climate forecasting', 'Disaster risk management', 0.4142)
# - ('heat stress', 'Adaptation', 0.4025)
# - ('saltwater intrusion', 'Adaptation', 0.3985)
# - ('water availability', 'Adaptation', 0.3753)
# - ('soil degradation', 'Adaptation', 0.3743)
# - ('natural capital', 'Nature-based solutions', 0.3719)
# - ('climate monitoring', 'Disaster risk management', 0.3624)
# - ('green infrastructure', 'Nature-based solutions', 0.3501)
# ----------------------
# PA PES PLM PPP RCF REDD+ RTC SCAP
#
# INSTRUMENT PREDICTIONS
#
#
# SECTOR PREDICTIONS
#
# ----------------------
# The road runs parallel and occasionally adjacent- to the coast.
#
# INSTRUMENT PREDICTIONS
#
#
# SECTOR PREDICTIONS
#
# ----------------------
# The fuel consumption is 10-35 % lower than for a Diesel-only driven lorry.
#
# INSTRUMENT PREDICTIONS
#
#
# SECTOR PREDICTIONS
# - ('diesel engine', 'Transport (general)', 0.4421)
# - ('internal combustion engine', 'Transport (general)', 0.3624)
# ----------------------
# Federal Register / Vol.
#
# INSTRUMENT PREDICTIONS
#
#
# SECTOR PREDICTIONS
#
# ----------------------
# No. 11507, Feb. 4, 1970, 35 F.R. 2573, which provided for prevention, control, and abatement of air pollution at Federal facilities, was superseded by Ex.
#
# INSTRUMENT PREDICTIONS
#
#
# SECTOR PREDICTIONS
# - ('air pollution', 'Environment', 0.3524)
# ----------------------

# %% [markdown]
# ### 1b) Symmetric semantic search

# %%
"""
Model choices (from https://www.sbert.net/docs/pretrained_models.html#semantic-search):
- multi-qa-MiniLM-L6-cos-v1: tuned for cosine similarity, which prefers retrieving shorter passages
- multi-qa-MiniLM-L6-dot-v1: tuned for dot product, which prefers retrieval of longer passages
"""

emb_symsearch = SentenceTransformer("multi-qa-MiniLM-L6-dot-v1")

clf_instruments_symm_cosine = CosineDistanceClassifier(
    schema = instruments, 
    sbert_model = "multi-qa-MiniLM-L6-cos-v1", 
    distance_measure= "cosine",
    concat_keywords_with_subsectors= True,
)

clf_sectors_symm_cosine = CosineDistanceClassifier(
    schema = sectors, 
    sbert_model = "multi-qa-MiniLM-L6-cos-v1", 
    distance_measure= "cosine",
    concat_keywords_with_subsectors= True,
)

# %%
THRESHOLD = 0.4

for _str in examples:
    print(_str)
    print()
    print("INSTRUMENT PREDICTIONS")
    print("\n".join([f"- {pred}" for pred in clf_instruments_symm_cosine.predict(_str, THRESHOLD)]))
    print()
    print("SECTOR PREDICTIONS")
    print("\n".join([f"- {pred}" for pred in clf_sectors_symm_cosine.predict(_str, THRESHOLD)]))
    print("----------------------")
# Out:
# Sources of Energy Supply At present, Bangladesh has energy supply from both renewable and nonrenewable sources, 38 percent of which comes from biomass (Figure 3.1).
#
# INSTRUMENT PREDICTIONS
#
#
# SECTOR PREDICTIONS
# - ('renewables', 'Energy production', 0.4862)
# - ('renewable energy', 'Energy production', 0.4853)
# - ('energy demand', 'Energy production', 0.468)
# - ('fossil fuels', 'Energy production', 0.4601)
# - ('offshore', 'Energy production', 0.4592)
# - ('onshore', 'Energy production', 0.4528)
# - ('natural gas', 'Energy production', 0.4483)
# - ('fossil fuel fires', 'Energy production', 0.4445)
# - ('biofuels', 'Energy production', 0.4425)
# - ('energy production', 'Energy production', 0.4246)
# - ('energy', 'Energy (general)', 0.4242)
# - ('energy industries', 'Energy production', 0.4236)
# - ('fuels', 'Energy production', 0.4177)
# - ('nuclear energy', 'Energy production', 0.4138)
# - ('power', 'Energy use', 0.4129)
# - ('gas', 'Energy production', 0.4089)
# - ('energy use', 'Energy use', 0.4076)
# - ('bioethanol', 'Energy production', 0.4069)
# - ('petroleum', 'Energy production', 0.4067)
# - ('energy research', 'Energy (general)', 0.4049)
# - ('nuclear', 'Energy production', 0.4027)
# - ('liquefaction', 'Energy production', 0.4003)
# ----------------------
# To put that in real-world context, roughly 35 jobs are created for each million board feet of wood processed.
#
# INSTRUMENT PREDICTIONS
#
#
# SECTOR PREDICTIONS
# - ('machinery', 'Industrial processes', 0.4027)
# ----------------------
# Research on the likelihood of disasters and the assessment of the likely social, economic and environmental impacts will be conducted regularly as an integral aspect of disaster preparedness and management.
#
# INSTRUMENT PREDICTIONS
# - ('climate risk', 'Monitoring and evaluation', 0.5701)
# - ('environmental assessment', 'Structures and processes', 0.4588)
# - ('risk assessments', 'Structures and processes', 0.4551)
# - ('climate vulnerabiliy', 'Monitoring and evaluation', 0.4419)
#
# SECTOR PREDICTIONS
# - ('climate-related perils', 'Disaster risk management', 0.6947)
# - ('natural disaster', 'Disaster risk management', 0.6658)
# - ('climate monitoring', 'Disaster risk management', 0.6576)
# - ('climate forecasting', 'Disaster risk management', 0.6406)
# - ('disaster risk management', 'Disaster risk management', 0.6175)
# - ('hurricane', 'Disaster risk management', 0.6165)
# - ('storm', 'Disaster risk management', 0.6082)
# - ('cyclone', 'Disaster risk management', 0.5842)
# - ('typhoon', 'Disaster risk management', 0.5794)
# - ('adaptation consultation', 'Disaster risk management', 0.578)
# - ('flooding', 'Disaster risk management', 0.5722)
# - ('physical risk', 'Disaster risk management', 0.5702)
# - ('extreme weather events', 'Disaster risk management', 0.5675)
# - ('landslide', 'Disaster risk management', 0.5548)
# - ('wildfire', 'Disaster risk management', 0.5538)
# - ('insurance', 'Disaster risk management', 0.5399)
# - ('avalanche', 'Disaster risk management', 0.531)
# - ('tornado', 'Disaster risk management', 0.5238)
# - ('early warning system', 'Disaster risk management', 0.5079)
# - ('infrastructure damage', 'Adaptation', 0.4454)
# ----------------------
# AEI10+A53: Mandatory blending of biofuels into mineral fuels.
#
# INSTRUMENT PREDICTIONS
#
#
# SECTOR PREDICTIONS
# - ('biofuels', 'Energy production', 0.579)
# - ('biodiesel', 'Energy production', 0.5193)
# - ('bioethanol', 'Energy production', 0.4609)
# - ('fuel exploitation', 'Energy production', 0.4436)
# - ('bioenergy', 'Energy production', 0.4403)
# - ('fuel processing', 'Energy production', 0.4362)
# - ('oil refinery', 'Energy production', 0.43)
# - ('offshore', 'Energy production', 0.4145)
# - ('fuel transformation', 'Energy production', 0.4137)
# - ('solid fuels', 'Energy production', 0.4055)
# - ('petroleum', 'Energy production', 0.4039)
# - ('biosolid', 'Agriculture (general)', 0.4)
# ----------------------
# Paragraph (4) of subsection (c) of such section is amended to read as follows: )
#
# INSTRUMENT PREDICTIONS
#
#
# SECTOR PREDICTIONS
#
# ----------------------
# 4702 PUBLIC LAW 110417OCT.
#
# INSTRUMENT PREDICTIONS
#
#
# SECTOR PREDICTIONS
#
# ----------------------
# Consult Repair Manual/Owners Guide Before Attempting To Service This Product.
#
# INSTRUMENT PREDICTIONS
#
#
# SECTOR PREDICTIONS
#
# ----------------------
# See Chapter 11.
#
# INSTRUMENT PREDICTIONS
#
#
# SECTOR PREDICTIONS
#
# ----------------------
# Levelized costs for electricity generation technologies, 2000 2050 .
#
# INSTRUMENT PREDICTIONS
#
#
# SECTOR PREDICTIONS
# - ('electricity subsidies', 'Energy use', 0.5464)
# - ('power industry', 'Energy production', 0.5025)
# - ('renewables', 'Energy production', 0.4858)
# - ('electricity distribution', 'Energy use', 0.4854)
# - ('renewable energy', 'Energy production', 0.4748)
# - ('energy demand', 'Energy production', 0.4691)
# - ('electricity', 'Energy use', 0.4529)
# - ('low-carbon technology', 'Energy production', 0.4401)
# - ('grid modernisation', 'Energy use', 0.4343)
# - ('nuclear', 'Energy production', 0.4334)
# - ('mining', 'Energy production', 0.427)
# - ('energy production', 'Energy production', 0.4256)
# - ('energy industries', 'Energy production', 0.4201)
# - ('nuclear energy', 'Energy production', 0.4185)
# - ('coal', 'Energy production', 0.412)
# - ('solar energy', 'Energy production', 0.4083)
# - ('energy technology', 'Energy use', 0.4081)
# - ('solar panels', 'Energy production', 0.4035)
# ----------------------
# fitting a curve to that data, can and should include some consideration of specific policy goals.
#
# INSTRUMENT PREDICTIONS
# - ('political strategy', 'Developing plans and stratgegies', 0.4339)
# - ('resilient infrastructure policy', 'Standards', 0.4324)
#
# SECTOR PREDICTIONS
#
# ----------------------
# The reforms we have made so far give Timor-Leste one of the most attractive taxation systems in the world for doing business.
#
# INSTRUMENT PREDICTIONS
#
#
# SECTOR PREDICTIONS
#
# ----------------------
# A central market infrastructure in Koror has become an issue of some urgency, especially given the inevitable increases in production resulting from the improved access to Babeldaob Island since the completion of the Compact Road.
#
# INSTRUMENT PREDICTIONS
# - ('investment', 'Infrastructure', 0.4249)
#
# SECTOR PREDICTIONS
#
# ----------------------
# Encourage alternative transport modalities (such as cycling, car-pooling or car-sharing) through urban planning and the development of an appropriate infrastructure for cycling (bike lanes, storage racks, special subway and train wagons/compartments for bikes) and extension of pedestrian areas, especially in large urban aglomerations.
#
# INSTRUMENT PREDICTIONS
# - ('infrastructure', 'Infrastructure', 0.4692)
# - ('public infrastructure', 'Infrastructure', 0.4364)
# - ('public spending', 'Infrastructure', 0.4095)
# - ('investment', 'Infrastructure', 0.4039)
#
# SECTOR PREDICTIONS
# - ('cycling infrastructure', 'Transport infrastructure', 0.7291)
# - ('cycling', 'Road transport', 0.672)
# - ('public transport', 'Transport infrastructure', 0.5695)
# - ('transport infrastructure', 'Transport infrastructure', 0.5644)
# - ('motorcycles', 'Road transport', 0.5624)
# - ('personal mobility', 'Transport (general)', 0.548)
# - ('electric bicyle', 'Road transport', 0.5354)
# - ('off-road transport', 'Transport (general)', 0.5341)
# - ('vehicles', 'Transport (general)', 0.5325)
# - ('cars', 'Road transport', 0.5313)
# - ('refueeling infrastructure', 'Transport infrastructure', 0.5303)
# - ('road infrasructure', 'Transport infrastructure', 0.5267)
# - ('urban infrastructure', 'Urban', 0.525)
# - ('local transport', 'Transport (general)', 0.5194)
# - ('electric cars', 'Road transport', 0.5134)
# - ('transport', 'Transport (general)', 0.5071)
# - ('domestic transport', 'Transport (general)', 0.5049)
# - ('airport infrastructure', 'Transport infrastructure', 0.4971)
# - ('low-emission vehicle', 'Transport (general)', 0.4957)
# - ('road transport', 'Road transport', 0.4919)
# - ('transport demand', 'Transport (general)', 0.4916)
# - ('urban green infrastructure', 'Nature-based solutions', 0.4849)
# - ('passenger transport', 'Transport (general)', 0.4826)
# - ('buses', 'Road transport', 0.4767)
# - ('charging infrastructure', 'Transport infrastructure', 0.4617)
# - ('low-carbon transport', 'Transport (general)', 0.4612)
# - ('resilient infrastructure', 'Adaptation', 0.4521)
# - ('vehicle emissions', 'Transport (general)', 0.4433)
# - ('urban crowding', 'Urban', 0.4421)
# - ('tourism', 'Tourism', 0.442)
# - ('interurban transport', 'Transport (general)', 0.4407)
# - ('rapid transit', 'Transport (general)', 0.4384)
# - ('minibuses', 'Road transport', 0.4355)
# - ('trucks', 'Road transport', 0.4331)
# - ('zero-emission vehicle', 'Transport (general)', 0.425)
# - ('international transport', 'Transport (general)', 0.4128)
# - ('infrastructure damage', 'Adaptation', 0.401)
# ----------------------
# The transaction costs and inefficiencies of seeking approval from the Centre for any changes are so high that most changes never get done and many budget lines remain unspent or under-spent.
#
# INSTRUMENT PREDICTIONS
#
#
# SECTOR PREDICTIONS
#
# ----------------------
# The Physical Planning Act, 2003.
#
# INSTRUMENT PREDICTIONS
# - ('planning', 'Management and planning', 0.5025)
# - ('spatial zoning', 'Management and planning', 0.488)
# - ('adaptation plan', 'Developing plans and stratgegies', 0.4877)
# - ('zoning', 'Management and planning', 0.4846)
# - ('plan', 'Developing plans and stratgegies', 0.4729)
# - ('planning body', 'Creating bodies/institutions', 0.4562)
# - ('strategic plan', 'Developing plans and stratgegies', 0.4537)
# - ('national strategy', 'Developing plans and stratgegies', 0.4449)
# - ('federal adaptation programme', 'Structures and processes', 0.4421)
# - ('white paper', 'Developing plans and stratgegies', 0.4193)
#
# SECTOR PREDICTIONS
# - ('physical risk', 'Disaster risk management', 0.4168)
# ----------------------
# To supplement the water available to farmers especially during the dry season the Agricultural Resource Management Project (ARMP) during the period 2011 2012 had undertaken the construction of water dams around the island of St. Kitts with three (3) completed and 1 under construction.
#
# INSTRUMENT PREDICTIONS
# - ('adaptation plan', 'Developing plans and stratgegies', 0.4095)
#
# SECTOR PREDICTIONS
# - ('irrigation', 'Agriculture (general)', 0.4511)
# - ('farm irrigation', 'Agriculture (general)', 0.4336)
# - ('water availability', 'Adaptation', 0.4318)
# - ('agricultural infrastructure', 'Agriculture (general)', 0.4135)
# ----------------------
# Improving management of both protection and production forests for REDD-plus Managing lands for multiple uses requires active monitoring, clear regulations, impact assessments strong enforcement and collaboration among stakeholders.
#
# INSTRUMENT PREDICTIONS
#
#
# SECTOR PREDICTIONS
# - ('forest management', 'Forestry', 0.5605)
# - ('forest protection', 'Forestry', 0.5581)
# - ('land management', 'Land use', 0.556)
# - ('forest restoration', 'Forestry', 0.5166)
# - ('forest onservation', 'Forestry', 0.5095)
# - ('urban forestry', 'Nature-based solutions', 0.5066)
# - ('land degradation', 'Land use', 0.5004)
# - ('rewetting', 'Land use', 0.493)
# - ('ecological interactions', 'Land use', 0.485)
# - ('green space management', 'Nature-based solutions', 0.4822)
# - ('natural forest', 'Forestry', 0.4688)
# - ('forest rehabilitation', 'Forestry', 0.4664)
# - ('forests', 'Forestry', 0.4644)
# - ('deforestation', 'Forestry', 0.4533)
# - ('cropland', 'Land use', 0.4519)
# - ('croplands', 'Agriculture (general)', 0.4475)
# - ('urban green infrastructure', 'Nature-based solutions', 0.4456)
# - ('green infrastructure', 'Nature-based solutions', 0.4443)
# - ('temperate forest', 'Forestry', 0.4425)
# - ('wildfire', 'Disaster risk management', 0.4395)
# - ('decomposition', 'Land use', 0.4365)
# - ('peatlands', 'Land use', 0.4363)
# - ('hunting', 'Land use', 0.4355)
# - ('forest conversion', 'Forestry', 0.4282)
# - ('trees', 'Forestry', 0.4233)
# - ('logging', 'Forestry', 0.4205)
# - ('crop burning', 'Agriculture (general)', 0.4168)
# - ('wetlands', 'Land use', 0.4161)
# - ('forestry', 'Forestry', 0.4128)
# - ('soil', 'Land use', 0.4092)
# - ('forest tundra', 'Forestry', 0.4078)
# - ('natural disaster', 'Disaster risk management', 0.4063)
# - ('soil quality', 'Agriculture (general)', 0.4058)
# - ('organic soil', 'Land use', 0.4043)
# - ('tropical forest', 'Forestry', 0.402)
# - ('pest regulation', 'Agriculture (general)', 0.4002)
# ----------------------
# The absence of effective data collection and evaluation mechanisms result in the inability of government to dynamically change course based on performance feedback.
#
# INSTRUMENT PREDICTIONS
# - ('federal adaptation programme', 'Structures and processes', 0.4089)
#
# SECTOR PREDICTIONS
#
# ----------------------
# (b) WAIVERS OF TRAINING REQUIREMENTS.Section 231(c) of the Trade Act of 1974 (19 U.S.C. 2291(c) is amended (1) in paragraph (1)(B) (A) by striking The worker possesses and inserting the following: (i) IN GENERAL.The worker possesses.
#
# INSTRUMENT PREDICTIONS
# - ('mandates', 'Obligations', 0.4466)
# - ('technical requirements', 'Obligations', 0.4415)
#
# SECTOR PREDICTIONS
#
# ----------------------
# based on the life cycle greenhouse gas emissions per unit of energy from fossil fuels in 2010 for the purposes of paragraph 2.
#
# INSTRUMENT PREDICTIONS
# - ('climate vulnerabiliy', 'Monitoring and evaluation', 0.4245)
#
# SECTOR PREDICTIONS
# - ('fossil fuels', 'Energy production', 0.5986)
# - ('agricultural carbon dioxide', 'Agricultural greenhouse gas emissions', 0.5849)
# - ('industrial carbon dioxide', 'Industrial greenhouse gas emissions', 0.5797)
# - ('industrial greenhouse gas emissions', 'Industrial greenhouse gas emissions', 0.5717)
# - ('fugitive emissions from fuels', 'Energy production', 0.5611)
# - ('fossil fuel fires', 'Energy production', 0.5471)
# - ('agricultural methane', 'Agricultural greenhouse gas emissions', 0.5468)
# - ('industrial nitrous oxide', 'Industrial greenhouse gas emissions', 0.5417)
# - ('agricultural greenhouse gas emissions', 'Agricultural greenhouse gas emissions', 0.5377)
# - ('agricultural nitrous oxide', 'Agricultural greenhouse gas emissions', 0.528)
# - ('fossil fuel phase-out', 'Energy production', 0.5221)
# - ('fuels', 'Energy production', 0.5124)
# - ('combustion', 'Energy production', 0.4834)
# - ('energy combustion activities', 'Energy production', 0.4786)
# - ('gas', 'Energy production', 0.477)
# - ('biodiesel', 'Energy production', 0.4767)
# - ('natural gas', 'Energy production', 0.4658)
# - ('solid fuels', 'Energy production', 0.4471)
# - ('renewables', 'Energy production', 0.4428)
# - ('vehicle emissions', 'Transport (general)', 0.4339)
# - ('fuel transformation', 'Energy production', 0.4329)
# - ('renewable energy', 'Energy production', 0.4286)
# - ('energy efficiency', 'Energy use', 0.4247)
# - ('energy demand', 'Energy production', 0.4239)
# - ('coal', 'Energy production', 0.4219)
# - ('energy research', 'Energy (general)', 0.4202)
# - ('petroleum', 'Energy production', 0.4186)
# - ('bioethanol', 'Energy production', 0.4135)
# - ('energy use', 'Energy use', 0.413)
# - ('negative emissions', 'Industrial processes', 0.407)
# ----------------------
# The NCCC has roles and responsibilities to coordinate and cooperate with concerned ministries and institutions aiming to: - Review and approve workplans and reports of the Climate Change Technical Team (CCTT) to be established in accordance with Article 4 of this Sub-Decree. 1.
#
# INSTRUMENT PREDICTIONS
#
#
# SECTOR PREDICTIONS
#
# ----------------------
# The situation is rather more complicated for precipitation.
#
# INSTRUMENT PREDICTIONS
#
#
# SECTOR PREDICTIONS
# - ('precipitation', 'Adaptation', 0.7193)
# - ('irrigation', 'Agriculture (general)', 0.4107)
# - ('climate-related perils', 'Disaster risk management', 0.4101)
# ----------------------
# Member States may agree on the statistical transfer of a specified amount of energy from renewable sources from one Member State to another Member State.
#
# INSTRUMENT PREDICTIONS
#
#
# SECTOR PREDICTIONS
# - ('renewables', 'Energy production', 0.4441)
# - ('renewable energy', 'Energy production', 0.4182)
# - ('energy availability', 'Adaptation', 0.4135)
# ----------------------
# - tax advantages deriving from the provisions governing works implemented to achieve energy savings, including those following on from the installation of renewables plants (Decree Law 201/2011).
#
# INSTRUMENT PREDICTIONS
# - ('tax advantages', 'Fiscal or financial incentives', 0.5773)
# - ('taxes', 'Fiscal or financial incentives', 0.5039)
# - ('tax relief', 'Fiscal or financial incentives', 0.5017)
# - ('tax system', 'Fiscal or financial incentives', 0.4938)
# - ('levy', 'Fiscal or financial incentives', 0.4844)
# - ('tariff', 'Fiscal or financial incentives', 0.4761)
# - ('fossil fuel subsidy', 'Fiscal or financial incentives', 0.4624)
# - ('tax credits', 'Fiscal or financial incentives', 0.4423)
# - ('feed-in tariff', 'Fiscal or financial incentives', 0.4034)
#
# SECTOR PREDICTIONS
# - ('electricity subsidies', 'Energy use', 0.547)
# - ('renewables', 'Energy production', 0.4612)
# - ('renewable energy', 'Energy production', 0.4558)
# - ('electricity', 'Energy use', 0.4513)
# - ('energy efficiency', 'Energy use', 0.449)
# - ('energy technology', 'Energy use', 0.4388)
# - ('grid modernisation', 'Energy use', 0.4316)
# - ('electricity distribution', 'Energy use', 0.4156)
# - ('energy use', 'Energy use', 0.4139)
# - ('power', 'Energy use', 0.402)
# - ('solar energy', 'Energy production', 0.4007)
# ----------------------
# The Austrian Strategy for Adaptation to Climate Change 119 Nr.
#
# INSTRUMENT PREDICTIONS
# - ('climate vulnerabiliy', 'Monitoring and evaluation', 0.4017)
#
# SECTOR PREDICTIONS
# - ('ecosystem-based adaptation', 'Nature-based solutions', 0.4759)
# - ('ocean acidification', 'Adaptation', 0.4667)
# - ('adaptation', 'Adaptation', 0.465)
# - ('desertification', 'Adaptation', 0.4562)
# - ('precipitation', 'Adaptation', 0.4348)
# - ('wind patterns', 'Adaptation', 0.4289)
# - ('temperature variability', 'Adaptation', 0.4085)
# - ('energy availability', 'Adaptation', 0.4053)
# - ('coastal erosion', 'Adaptation', 0.4047)
# ----------------------
# PA PES PLM PPP RCF REDD+ RTC SCAP
#
# INSTRUMENT PREDICTIONS
#
#
# SECTOR PREDICTIONS
#
# ----------------------
# The road runs parallel and occasionally adjacent- to the coast.
#
# INSTRUMENT PREDICTIONS
#
#
# SECTOR PREDICTIONS
# - ('cycling', 'Road transport', 0.4258)
# ----------------------
# The fuel consumption is 10-35 % lower than for a Diesel-only driven lorry.
#
# INSTRUMENT PREDICTIONS
#
#
# SECTOR PREDICTIONS
# - ('diesel engine', 'Transport (general)', 0.5569)
# - ('lorries', 'Road transport', 0.4573)
# - ('jet fuel', 'Air transport', 0.4422)
# - ('trucks', 'Road transport', 0.4398)
# - ('gasoline', 'Transport (general)', 0.4395)
# - ('petrol engine', 'Transport (general)', 0.4308)
# ----------------------
# Federal Register / Vol.
#
# INSTRUMENT PREDICTIONS
#
#
# SECTOR PREDICTIONS
#
# ----------------------
# No. 11507, Feb. 4, 1970, 35 F.R. 2573, which provided for prevention, control, and abatement of air pollution at Federal facilities, was superseded by Ex.
#
# INSTRUMENT PREDICTIONS
#
#
# SECTOR PREDICTIONS
# - ('air pollution', 'Environment', 0.4289)
# ----------------------
